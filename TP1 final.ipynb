# %%
import pymongo
import json
from pprint import pprint
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
db = client.metflix
movies = db.movies
users = db.users
print('connexion success')
db.movies.drop()
db.users.drop()
metflix = client["metflix"]
rocky = {"title": "Rocky", "year": 1976}
movies.insert_one(rocky)
items = movies.find({"title": "Rocky"})
for item in items:
    print(item)

moi = {"nom": "Pomart", "Prenom": "Thomas"}


users.insert_one(moi)
users = users.find({"nom": "Pomart"})
for user in users:
    print(user)

movieslist = [
    { "_id": "tt0075148", "title": "Rocky", "year": 1976 },
    { "_id": "tt0073195", "title": "Jaws", "year": 1975 },
    { "_id": "tt0082694", "title": "Mad Max 2", "year": 1981 },
    { "_id": "tt0082971", "title": "Raiders", "year": 1981 }
]
try:
    movies.insert_many(movieslist)
except:
    print("Erreur Insertion")

movies1981 = movies.find({"year": 1981})
print('Film de 1981')
for movie in movies1981:
    print(movie)

allmovies = movies.find()
print("Tout les films")
for movie in allmovies:
    print(movie)

Jaws = movies.find_one({"title": "Jaws"})
print('Film Jaws')
print(Jaws)

db2 = client.movies_artist
movies2 = db2.movies
movies_artist = client["movies_artist"]
with open('movies.json') as f:
    file_data = json.load(f)
with open('movies_suite.json') as f2:
    file_data2 = json.load(f2)

movies2.drop()
movies2.insert_many(file_data)
movies2.insert_many(file_data2)
testjson = movies2.find()
for movies in testjson:
    pprint(movies)
for x in movies2.find({},{ "_id": 0, "title": 1 }).limit(12).sort("title", 1):
  print(x)
for x in movies2.find({},{ "_id": 0, "title": 1 }).limit(12).sort("title", -1):
  print(x)

v1979 = movies2.find({"year": 1979},{ "_id": 0, "title": 1, "year":1 }).count()
print(v1979)
# Out:
# ok
# {'_id': ObjectId('6005576045c76fc2d314d579'), 'title': 'Rocky', 'year': 1976}
# {'_id': ObjectId('6005576045c76fc2d314d57a'), 'nom': 'Pomart', 'Prenom': 'Thomas'}
# Film de 1981
# {'_id': 'tt0082694', 'title': 'Mad Max 2', 'year': 1981}
# {'_id': 'tt0082971', 'title': 'Raiders', 'year': 1981}
# Tout les films
# {'_id': ObjectId('6005576045c76fc2d314d579'), 'title': 'Rocky', 'year': 1976}
# {'_id': 'tt0075148', 'title': 'Rocky', 'year': 1976}
# {'_id': 'tt0073195', 'title': 'Jaws', 'year': 1975}
# {'_id': 'tt0082694', 'title': 'Mad Max 2', 'year': 1981}
# {'_id': 'tt0082971', 'title': 'Raiders', 'year': 1981}
# Film Jaws
# {'_id': 'tt0073195', 'title': 'Jaws', 'year': 1975}
# {'_id': 'movie:1',
#  'actors': [{'_id': 'artist:15', 'role': 'John Ferguson'},
#             {'_id': 'artist:16', 'role': 'Madeleine Elster'},
#             {'_id': 'artist:282', 'role': None}],
#  'country': 'DE',
#  'director': {'_id': 'artist:3'},
#  'genre': 'drama',
#  'summary': 'Scottie Ferguson, ancien inspecteur de police, est sujet au '
#             "vertige depuis qu'il a vu mourir son collÃ¨gue. Elster, son ami, "
#             'le charge de surveiller sa femme, Madeleine, ayant des tendances '
#             'suicidaires. Amoureux de la jeune femme Scottie ne remarque pas '
#             'le piÃ¨ge qui se trame autour de lui et dont il va Ãªtre la '
#             'victime... ',
#  'title': 'Vertigo',
#  'year': 1958}
# {'_id': 'movie:2',
#  'actors': [{'_id': 'artist:5', 'role': 'Ripley'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'Science-fiction',
#  'summary': "PrÃ¨s d'un vaisseau spatial Ã©chouÃ© sur une lointaine planÃ¨te, "
#             'des Terriens en mission dÃ©couvrent de bien Ã©tranges "oeufs". '
#             "Ils en ramÃ¨nent un Ã\xa0 bord, ignorant qu'ils viennent "
#             "d'introduire parmi eux un huitiÃ¨me passager particuliÃ¨rement "
#             'fÃ©roce et meurtrier. ',
#  'title': 'Alien',
#  'year': 1979}
# {'_id': 'movie:3',
#  'actors': [{'_id': 'artist:109', 'role': 'Rose DeWitt Bukater'},
#             {'_id': 'artist:110', 'role': 'Jack Dawson'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:6'},
#  'genre': 'drama',
#  'summary': 'Conduite par Brock Lovett, une expÃ©dition amÃ©ricaine fouillant '
#             "l'Ã©pave du Titanic remonte Ã\xa0 la surface le croquis d'une "
#             'femme nue. AlertÃ©e par les mÃ©dias la dame en question, Rose '
#             "DeWitt Bukater, aujourd'hui centenaire, rejoint les lieux du "
#             "naufrage, d'oÃ¹ elle entreprend de conter le rÃ©cit de son "
#             'fascinant, Ã©trange et tragique voyage... ',
#  'title': 'Titanic',
#  'year': 1997}
# {'_id': 'movie:4',
#  'actors': [],
#  'country': 'FR',
#  'director': {'_id': 'artist:9'},
#  'genre': 'drama',
#  'summary': None,
#  'title': 'Sacrifice',
#  'year': 1986}
# {'_id': 'movie:5',
#  'actors': [{'_id': 'artist:11', 'role': 'Sean Archer/Castor Troy'},
#             {'_id': 'artist:12', 'role': 'Castor Troy/Sean Archer'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:10'},
#  'genre': 'Action',
#  'summary': "Directeur d'une unitÃ© anti-terroriste, Sean Archer recherche "
#             'Castor Troy, un criminel responsable de la mort de son fils six '
#             "ans plus tÃ´t. Il parvient Ã\xa0 l'arrÃªter mais apprend que Troy "
#             'a cachÃ© une bombe au Palais des CongrÃ¨s de Los Angeles. Seul le '
#             "frÃ¨re de Troy peut la dÃ©samorcer et, pour l'approcher, Archer "
#             'se fait greffer le visage de Troy. ',
#  'title': 'Volte/Face',
#  'year': 1997}
# {'_id': 'movie:6',
#  'actors': [{'_id': 'artist:14', 'role': 'Constable Ichabod Crane'},
#             {'_id': 'artist:96', 'role': 'Katrina Anne Van Tassel'},
#             {'_id': 'artist:97', 'role': 'Le cavalier'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:13'},
#  'genre': 'Fantastique',
#  'summary': 'Nouvelle Angleterre, 1799. A Sleepy Hollow, plusieurs cadavres '
#             'sont retrouvÃ©s dÃ©capitÃ©s. '
#             'La                                      rumeur attribue ces '
#             'meurtres Ã\xa0 un cavalier lui-mÃªme sans tÃªte. Mais le fin '
#             'limier                                      new-yorkais Ichabod '
#             'Crane ne croit pas en ses aberrations. TombÃ© sous le charme de '
#             'la                                      vÃ©nÃ©neuse Katrina, il '
#             'mÃ¨ne son enquÃªte au coeur des sortilÃ¨ges de Sleepy Hollow.. ',
#  'title': 'Sleepy Hollow',
#  'year': 1999}
# {'_id': 'movie:7',
#  'actors': [{'_id': 'artist:18', 'role': 'Lester Burnham'},
#             {'_id': 'artist:19', 'role': 'Carolyn Burnham'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:17'},
#  'genre': 'ComÃ©die',
#  'summary': 'Lester Burnham, sa femme Carolyn et leur fille Jane mÃ¨nent '
#             'apparemment une vie des plus heureuses dans leur belle banlieue. '
#             'Mais derriÃ¨re cette respectable faÃ§ade se tisse une Ã©trange et '
#             'grinÃ§ante tragi-comÃ©die familiale oÃ¹ dÃ©sirs inavouÃ©s, '
#             'frustrations et violences refoulÃ©es conduiront inexorablement un '
#             'homme vers la mort. ',
#  'title': 'American Beauty',
#  'year': 1999}
# {'_id': 'movie:8',
#  'actors': [{'_id': 'artist:20', 'role': 'William Munny'},
#             {'_id': 'artist:21', 'role': 'Little Bill Dagget'},
#             {'_id': 'artist:22', 'role': 'Ned Logan'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:20'},
#  'genre': 'Western',
#  'summary': "LÃ©gendaire hors-la-loi, William Munny s'est reconverti depuis "
#             'onze ans en paisible fermier. Il reprend nÃ©anmoins les armes '
#             'pour traquer deux tueurs en compagnie de son vieil ami Ned Logan. '
#             "Mais ce dernier est capturÃ©, puis Ã©xÃ©cute. L'honneur et "
#             "l'amitiÃ© imposent dÃ¨s lors Ã\xa0 Munny de redevenir une "
#             "derniÃ¨re fois le hÃ©ros qu'il fut jadis... ",
#  'title': 'Impitoyable',
#  'year': 1992}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'drama',
#  'summary': 'Le gÃ©nÃ©ral romain Maximus est le plus '
#             "fidÃ¨le                    soutien de l'empereur Marc AurÃ¨le, "
#             "qu'il a                    conduit de victoire en victoire avec "
#             'une                    bravoure et un dÃ©vouement '
#             'exemplaires.                    Jaloux du prestige de Maximus, et '
#             "plus                    encore de l'amour que lui voue "
#             "l'empereur,                    le fils de Marc-AurÃ¨le, Commode, "
#             "s'arroge                    brutalement le pouvoir, puis "
#             "ordonne                    l'arrestation du gÃ©nÃ©ral et son "
#             'exÃ©cution.                    Maximus Ã©chappe Ã\xa0 ses '
#             'assassins mais ne peut                    empÃªcher le massacre '
#             'de sa famille. CapturÃ©                    par un marchand '
#             "d'esclaves, il devient                    gladiateur et prÃ©pare "
#             'sa vengeance.',
#  'title': 'Gladiator',
#  'year': 2000}
# {'_id': 'movie:10',
#  'actors': [{'_id': 'artist:24', 'role': 'Deckard'},
#             {'_id': 'artist:25', 'role': 'Batty'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'Action',
#  'summary': 'En 2019, lors de la dÃ©cadence de Los Angeles, des Ãªtres '
#             'synthÃ©tiques, sans pensÃ©e, sans Ã©motions, suffisent aux '
#             "diffÃ©rents travaux d'entretien. Leur durÃ©e de vie n'excÃ¨de pas "
#             '4 annÃ©es. Un jour, ces ombres humaines se rÃ©voltent et on '
#             'charge les tueurs, appelÃ©s Blade Runner, de les abattre... ',
#  'title': 'Blade Runner',
#  'year': 1982}
# {'_id': 'movie:11',
#  'actors': [{'_id': 'artist:27', 'role': 'McClane'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:26'},
#  'genre': 'Action',
#  'summary': 'John Mc Clane, policier new-yorkais, vient passer Noel a Los '
#             'Angeles aupres de sa femme. Dans le building ou elle travaille, '
#             'il se retrouve temoin de la prise en otage de tout le personnel '
#             'par 12 terroristes. Objectif de ces derniers, vider les coffres '
#             'de la societe. Cache mais isole, il entreprend de prevenir '
#             "l'exterieur...",
#  'title': 'PiÃ¨ge de cristal',
#  'year': 1988}
# {'_id': 'movie:12',
#  'actors': [{'_id': 'artist:27', 'role': 'McClane'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:28'},
#  'genre': 'Action',
#  'summary': " Venu attendre sa femme a l'aÃ©roport, le policier John McClane "
#             'remarque la prÃ©sence de terroristes qui ont pris le contrÃ´le '
#             "des pistes, empÃªchant tout avion d'atterrir et menaÃ§ant de "
#             "laisser les appareils en vol tourner jusqu'Ã\xa0 Ã©puisement de "
#             "leur kÃ©rosÃ¨ne. John n'a devant lui que 58 minutes pour Ã©viter "
#             'la catastrophe... ',
#  'title': '58 minutes pour vivre',
#  'year': 1990}
# {'_id': 'movie:13',
#  'actors': [{'_id': 'artist:30', 'role': 'Van Gogh'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:29'},
#  'genre': 'drama',
#  'summary': 'Les derniers jours de la vie de Vincent Van Gogh, rÃ©fugiÃ© Ã\xa0 '
#             'Auvers-sur-Oise, prÃ¨s de chez son ami et protecteur le docteur '
#             'Gachet, un ami de son frÃ¨re ThÃ©o. Ce peintre maudit, que les '
#             'villageois surlast_namemaient "le fou", n\'avait alors plus que '
#             "deux mois Ã\xa0 vivre, qu'il passa en peignant un tableau par "
#             'jour. ',
#  'title': 'Van Gogh',
#  'year': 1990}
# {'_id': 'movie:14',
#  'actors': [{'_id': 'artist:18', 'role': 'Doe'},
#             {'_id': 'artist:22', 'role': 'Somerset'},
#             {'_id': 'artist:32', 'role': 'Mills'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:31'},
#  'genre': 'crime',
#  'summary': 'A New York, un criminel anonyme a dÃ©cidÃ© de commettre 7 '
#             'meurtres basÃ©s sur les 7 pÃªchÃ©s capitaux Ã©noncÃ©s dans la '
#             'Bible : gourmandise, avarice, paresse, orgueil, luxure, envie et '
#             'colÃ¨re. Vieux flic blasÃ© Ã\xa0 7 jours de la retraite, '
#             "l'inspecteur Somerset mÃ¨ne l'enquÃªte tout en formant son "
#             "remplaÃ§ant, l'ambitieux inspecteur David Mills... ",
#  'title': 'Seven',
#  'year': 1995}
# {'_id': 'movie:15',
#  'actors': [{'_id': 'artist:27', 'role': 'Cole'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:33'},
#  'genre': 'Science-fiction',
#  'summary': None,
#  'title': 'Twelve Monkeys',
#  'year': 1995}
# {'_id': 'movie:16',
#  'actors': [{'_id': 'artist:35', 'role': 'Baskerville'},
#             {'_id': 'artist:36', 'role': 'de Melk'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:34'},
#  'genre': 'crime',
#  'summary': "En l'an 1327, dans une abbaye bÃ©nÃ©dictine, le moine franciscain "
#             'Guillaume de Baskerville, accompagnÃ© de son jeune novice Adso, '
#             'enquÃªte sur de mystÃ©rieuses morts qui frappent la confrÃ©rie. '
#             'Le secret semble rÃ©sider dans la bibliothÃ¨que, oÃ¹ le vieux '
#             'Jorge garde jalousement un livre jugÃ© maudit. ',
#  'title': 'Le last_name de la rose',
#  'year': 1986}
# {'_id': 'movie:17',
#  'actors': [{'_id': 'artist:11', 'role': 'Vincent Vega'},
#             {'_id': 'artist:27', 'role': 'Butch Coolidge'},
#             {'_id': 'artist:37', 'role': 'Jimmy Dimmick'},
#             {'_id': 'artist:38', 'role': 'Jules Winnfield'},
#             {'_id': 'artist:39', 'role': 'Jody'},
#             {'_id': 'artist:40', 'role': 'Mia Wallace'},
#             {'_id': 'artist:97', 'role': 'Capt. Koons'},
#             {'_id': 'artist:98', 'role': 'Winston "The Wolf" Wolfe'},
#             {'_id': 'artist:99', 'role': 'Pumpkin (Ringo)'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'Action',
#  'summary': "Pulp Fiction dÃ©crit l'odyssÃ©e sanglante et burlesque de petits "
#             "malfrats dans la jungle de Hollywood, ou s'entrecroisent les "
#             "destins de deux petits tueurs, d'un dangereux gangster mariÃ© "
#             "Ã\xa0 une camÃ©e, d'un boxeur roublard, de prÃªteurs sur gages "
#             "sadiques, d'un caÃ¯d Ã©lÃ©gant et dÃ©vouÃ©, d'un dealer bon mari "
#             'et de deux tourtereaux Ã\xa0 la gachette facile... ',
#  'title': 'Pulp fiction',
#  'year': 1994}
# {'_id': 'movie:18',
#  'actors': [{'_id': 'artist:42', 'role': 'Mary Jensen Matthews'},
#             {'_id': 'artist:43', 'role': 'Pat Healy'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:41'},
#  'genre': 'ComÃ©die',
#  'summary': "Pour retrouver l'amour de sa jeunesse, la belle Mary, "
#             'Ted-le-looser engage Pat Healy, un privÃ©. SubjugÃ© par la jeune '
#             'femme, ce dernier tente de la sÃ©duire en se faisant passer pour '
#             'un architecte. Il cache la vÃ©ritÃ© Ã\xa0 Ted et fait cause '
#             'commune avec Tucker, un autre prÃ©tendant, pour se dÃ©barrasser '
#             "de l'encombrant Ted... ",
#  'title': 'Mary Ã\xa0 tout prix',
#  'year': 1998}
# {'_id': 'movie:19',
#  'actors': [{'_id': 'artist:44', 'role': 'Terminator'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:6'},
#  'genre': 'Science-fiction',
#  'summary': "Deux creatures venues du futur debarquent sur terre. L'une "
#             "d'entre elles, le Terminator, doit eliminer une certaine Sarah "
#             "Connor, qui doit enfanter celui qui sera le chef d'un groupe de "
#             "resistants. L'autre, Kyle Reese, est charge par les rebelles de "
#             'defendre Sarah... ',
#  'title': 'Terminator',
#  'year': 1984}
# {'_id': 'movie:20',
#  'actors': [{'_id': 'artist:46', 'role': 'Martin Brody'},
#             {'_id': 'artist:47', 'role': 'Quint'},
#             {'_id': 'artist:48', 'role': 'Matt Hooper'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:45'},
#  'genre': 'Horreur',
#  'summary': "Dans la station balnÃ©aire d'Amityville, un requin gÃ©ant frappe "
#             "Ã\xa0 plusieurs reprises. Soucieux d'une bonne saison "
#             'touristique, le maire interdit au sherif Brody de fermer les '
#             'plages. Une prime est offerte et le cÃ©lÃ¨bre chasseur de requin '
#             "Quint se lance avec Brody et l'ichtyologue Hooper Ã\xa0 la "
#             'poursuite du monstre... ',
#  'title': 'Les dents de la mer',
#  'year': 1975}
# {'_id': 'movie:21',
#  'actors': [{'_id': 'artist:50', 'role': 'Dr. Hannibal Lecter'},
#             {'_id': 'artist:51', 'role': 'Clarice Starling'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:49'},
#  'genre': 'crime',
#  'summary': "Afin de retrouver la piste d'un tueur surlast_namemÃ© Buffalo "
#             "Bill car il scalpe les femmes qu'il assassine, la jeune stagiaire "
#             "du FBI Clarice Starling est dÃ©pÃªchÃ©e auprÃ¨s d'Hannibal "
#             'Lecter, prisonnier pour avoir dÃ©vorÃ© ses victimes. La '
#             'coopÃ©ration de ce dernier devrait permettre Ã\xa0 Clarice de '
#             "saisir et d'anticiper le comportement de Buffalo... ",
#  'title': 'Le silence des agneaux',
#  'year': 1990}
# {'_id': 'movie:22',
#  'actors': [{'_id': 'artist:59', 'role': 'Dr. Nikos Tatopoulos'},
#             {'_id': 'artist:60', 'role': 'Philippe RoachÃ©'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:58'},
#  'genre': 'Action',
#  'summary': 'Issu des radiations atomiques engendrÃ©es par les essais '
#             'nuclÃ©aires en PolynÃ©sie, un monstre gigantesque, aussi haut '
#             "qu'un building, se dirige vers New York, semant le chaos sur son "
#             'passage. Pour tenter de stopper cette crÃ©ature destructrice, '
#             "l'armÃ©e s'associe Ã\xa0 une Ã©quipe de scientifiques amÃ©ricains "
#             'et Ã\xa0 un Ã©nigmatique enquÃªteur franÃ§ais... ',
#  'title': 'Godzilla',
#  'year': 1998}
# {'_id': 'movie:23',
#  'actors': [{'_id': 'artist:62', 'role': 'Neo'},
#             {'_id': 'artist:63', 'role': 'Morpheus'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:61'},
#  'genre': 'Science-fiction',
#  'summary': 'Dans un monde oÃ¹ tout ce qui semble rÃ©el est en fait Ã©laborÃ© '
#             "par l'univers Ã©lectronique baptisÃ© la Matrice, NÃ©o, un "
#             "programmeur, est contactÃ© par un certain Morpheus. D'aprÃ¨s lui, "
#             'NÃ©o serait le LibÃ©rateur tant attendu, le seul capable de '
#             "mettre en Ã©chec l'omnipotence de la Matrice et rendre ses droits "
#             'Ã\xa0 la rÃ©alitÃ©... ',
#  'title': 'Matrix',
#  'year': 1999}
# {'_id': 'movie:24',
#  'actors': [{'_id': 'artist:60', 'role': 'Franz Krieger'},
#             {'_id': 'artist:65', 'role': 'Ethan Hunt'},
#             {'_id': 'artist:66', 'role': 'Jim Phelps'},
#             {'_id': 'artist:67', 'role': 'Claire Phelps'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:64'},
#  'genre': 'Action',
#  'summary': "ChargÃ© d'une nouvelle mission, l'agent du contre espionnage "
#             'Ethan Hunt tombe avec son Ã©quipe dans un piÃ¨ge sanglant. Seul '
#             'survivant avec Claire, la jeune Ã©pouse de son regrettÃ© chef Jim '
#             'Phelps, Ethan se retrouve accusÃ© de trahison. En fuite, il '
#             "prÃ©pare sa contre-attaque, recrutant l'homme de main Krieger et "
#             'le pirate informatique Luther... ',
#  'title': 'Mission: Impossible',
#  'year': 1996}
# {'_id': 'movie:25',
#  'actors': [],
#  'country': 'JP',
#  'director': {'_id': 'artist:68'},
#  'genre': 'Guerre',
#  'summary': 'Au XVIe siecle, Takeda, grand seigneur trouble par les guerres '
#             "civiles de son pays, fait appel a un Kagemusha pour l'aider dans "
#             'ses batailles. Takeda est blesse et avant de mourir, il exige que '
#             "sa mort soit tenue secrete pendant trois ans afin d'eviter un "
#             'eclatement du clan. Le Kagemusha devra le remplacer... ',
#  'title': 'Kagemusha',
#  'year': 1980}
# {'_id': 'movie:26',
#  'actors': [{'_id': 'artist:20', 'role': 'Luther Whitney'},
#             {'_id': 'artist:21', 'role': 'Le prÃ©sident Richmond'},
#             {'_id': 'artist:69', 'role': 'Seth Frank'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:20'},
#  'genre': 'crime',
#  'summary': "Luther Whitney est l'as des cambrioleurs. OccupÃ© Ã\xa0 vider le "
#             "coffre de l'influent Walter Sullivan, il est tÃ©moin d'un meurtre "
#             'sadique impliquant le PrÃ©sident des Etats-Unis et les services '
#             "secrets. SoupÃ§onnÃ© par la police d'en Ãªtre l'auteur, il se "
#             'retrouve Ã©galement traquÃ© par les tueurs, qui ont compris '
#             "qu'ils ont Ã©tÃ© observÃ©s.",
#  'title': 'Les pleins pouvoirs',
#  'year': 1997}
# {'_id': 'movie:27',
#  'actors': [{'_id': 'artist:72', 'role': 'Inspecteur Cruchot'},
#             {'_id': 'artist:73', 'role': 'Adjudant Gerber'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:71'},
#  'genre': 'ComÃ©die',
#  'summary': 'En anglais: Gendarme and the Creatures from Outer Space !',
#  'title': 'Le gendarme et les extra-terrestres',
#  'year': 1978}
# {'_id': 'movie:28',
#  'actors': [{'_id': 'artist:57', 'role': 'Dr. Ian Malcolm'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:45'},
#  'genre': 'Horreur',
#  'summary': None,
#  'title': 'Le monde perdu',
#  'year': 1997}
# {'_id': 'movie:29',
#  'actors': [{'_id': 'artist:65', 'role': 'Charlie Babbitt'},
#             {'_id': 'artist:80', 'role': 'Raymond Babbitt'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:79'},
#  'genre': 'drama',
#  'summary': 'A la mort de son pÃ¨re, Charlie se voit dÃ©possÃ©der de son '
#             "hÃ©ritage par un frÃ¨re dont il ignorait l'existence, Raymond. "
#             'Celui-ci est autiste et vit dans un hÃ´pital psychiatrique. '
#             "Charlie enlÃ¨ve Raymond afin de prouver qu'il est capable de s'en "
#             "occuper et de toucher l'hÃ©ritage. ",
#  'title': 'Rain Man',
#  'year': 1988}
# {'_id': 'movie:30',
#  'actors': [{'_id': 'artist:53', 'role': 'Iceman'},
#             {'_id': 'artist:65', 'role': 'Lt. Pete Maverick Mitchell'},
#             {'_id': 'artist:82', 'role': 'Charlotte Blackwood'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:81'},
#  'genre': 'Action',
#  'summary': ' Pilote de chasse Ã©mÃ©rite mais casse-cou Maverick Mitchell est '
#             "admis Ã\xa0 Top Gun, l'Ã©cole de l'Ã©lite de l'aÃ©ronavale. Son "
#             'manque de prudence lui attire les foudres de ses supÃ©rieurs et '
#             'la haine de certains coÃ©quipiers. Il perd subitement la foi et '
#             "confiance en lui quand son ami de toujours meurt en vol et qu'il "
#             "s'en croit responsable... ",
#  'title': 'Top Gun',
#  'year': 1986}
# {'_id': 'movie:31',
#  'actors': [{'_id': 'artist:75', 'role': 'Nathalie Morin'},
#             {'_id': 'artist:76', 'role': 'Christiane'},
#             {'_id': 'artist:84', 'role': 'Jean-Claude Dus'},
#             {'_id': 'artist:85', 'role': 'JÃ©rÃ´me'},
#             {'_id': 'artist:86', 'role': 'Popeye'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:83'},
#  'genre': 'ComÃ©die',
#  'summary': "Apres avoir passe des vacances d'ete ensemble, Bernard, Nathalie, "
#             'Gigi, Jerome, Popeye, Jean-Claude et Christiane se retrouvent aux '
#             "sports d'hiver. Tous ont leurs problemes de coeur ou d'argent, "
#             'mais il faut bien vivre avec. Avant de se separer, se perdre dans '
#             'la montagne leur permet de gouter aux joies de la "vraie vie" '
#             'paysanne... ',
#  'title': 'Les bronzÃ©s font du ski',
#  'year': 1979}
# {'_id': 'movie:32',
#  'actors': [{'_id': 'artist:20', 'role': None}],
#  'country': 'IT',
#  'director': {'_id': 'artist:219'},
#  'genre': 'Western',
#  'summary': 'Pendant la Guerre de SÃ©cession, trois hommes, prÃ©fÃ©rant '
#             "s'intÃ©resser Ã\xa0 leur profit personnel, se lancent Ã\xa0 la "
#             "recherche d'un coffre contenant 200 000 dollars en piÃ¨ces d'or "
#             "volÃ©s Ã\xa0 l'armÃ©e sudiste. Tuco sait que le trÃ©sor se trouve "
#             'dans un cimetiÃ¨re, tandis que Joe connaÃ®t le last_name inscrit '
#             'sur la pierre tombale qui sert de cache. Chacun a besoin de '
#             "l'autre. Mais un troisiÃ¨me homme entre dans la course : Setenza, "
#             "une brute qui n'hÃ©site pas Ã\xa0 massacrer femmes et enfants "
#             'pour parvenir Ã\xa0 ses fins.',
#  'title': 'Le bon, la brute et le truand',
#  'year': 1966}
# {'_id': 'movie:33',
#  'actors': [{'_id': 'artist:88', 'role': 'Bates'},
#             {'_id': 'artist:89', 'role': 'Lila Crane'},
#             {'_id': 'artist:90', 'role': 'Marion Crane'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:3'},
#  'genre': 'Thriller',
#  'summary': 'AprÃ¨s avoir volÃ© 40 000 dollars, Marion Crane se rend dans un '
#             'motel tenu par Norman Bates. Elle est poignardÃ©e sous sa douche '
#             'par une femme. Norman fait disparaitre le corps et les affaires '
#             'de la jeune femme. Mais Sam, le fiancÃ© de Marion, inquiet de ne '
#             'pas avoir de nouvelles, engage un dÃ©tective pour la '
#             'retrouver... ',
#  'title': 'Psychose',
#  'year': 1960}
# {'_id': 'movie:34',
#  'actors': [{'_id': 'artist:24', 'role': 'Han Solo'},
#             {'_id': 'artist:92', 'role': 'Luke Skywalker'},
#             {'_id': 'artist:93', 'role': 'Princesse Leia'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:91'},
#  'genre': 'Science-fiction',
#  'summary': "Luke Skywalker s'introduit chez Jabba pour delivrer Han Solo et "
#             "la princesse Leia, tandis que l'Empire reconstruit une deuxieme "
#             '"Etoile de la Mort". Luke se rend ensuite au chevet de Yoda qui '
#             'est mourant. Il lui apprend que Leia est sa soeur. Luke forme un '
#             "commando pour attaquer l'Etoile, tandis qu'il affronte son pere, "
#             'Darth Vador... ',
#  'title': 'Le retour du Jedi',
#  'year': 1983}
# {'_id': 'movie:35',
#  'actors': [{'_id': 'artist:94', 'role': 'Mitch Brenner'},
#             {'_id': 'artist:95', 'role': 'Melanie Daniels'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:3'},
#  'genre': 'Horreur',
#  'summary': 'Melanie Daniels se rend Ã\xa0 Bodega Bay pour offrir deux '
#             "perruches en cage Ã\xa0 Cathy, la soeur de l'avocat Mitch "
#             'Brenner. AttaquÃ©e par une mouette, Melanie reste chez les '
#             "Brenner pour la nuit. Mais d'autres Ã©vÃ¨nements Ã©tranges se "
#             'produisent: des enfants sont blessÃ©s par des corbeaux et la '
#             "maison de Mitch est envahie par des milliers d'oiseaux. ",
#  'title': 'Les oiseaux',
#  'year': 1963}
# {'_id': 'movie:36',
#  'actors': [{'_id': 'artist:37', 'role': 'Mr. Brown'},
#             {'_id': 'artist:98', 'role': 'Mr. White/Larry'},
#             {'_id': 'artist:99', 'role': 'Freddy Newendyke/Mr. Orange'},
#             {'_id': 'artist:100', 'role': 'Nice Guy Eddie'},
#             {'_id': 'artist:215', 'role': 'Mr Blonde'},
#             {'_id': 'artist:217', 'role': 'Mr Pink'},
#             {'_id': 'artist:218', 'role': 'Mr Blue'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'crime',
#  'summary': 'AprÃ¨s un hold-up manquÃ©, des cambrioleurs de haut vol font '
#             'leurs comptes dans une confrontation violente, pour dÃ©couvrir '
#             "lequel d'entre eux les a trahis. Voleurs de profession, Joe Cabot "
#             'et son fils Eddie engagent un groupe de six criminels pour le '
#             "cambriolage d'un diamantaire. MalgrÃ© toutes les prÃ©cautions "
#             "prises, la police est sur place le jour J, et l'opÃ©ration se "
#             'solde par un massacre. Les survivants du gang se rÃ©unissent pour '
#             "rÃ¨gler leurs comptes, chacun soupÃ§onnant l'autre d'avoir "
#             'trahi. ',
#  'title': 'Reservoir dogs',
#  'year': 1992}
# {'_id': 'movie:37',
#  'actors': [{'_id': 'artist:65', 'role': 'Docteur William "Bill" Harford'},
#             {'_id': 'artist:102', 'role': 'Alice Harford'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:101'},
#  'genre': 'Thriller',
#  'summary': 'Un couple de bourgeois, cÃ©dant Ã\xa0 la jalousie et Ã\xa0 '
#             "l'obsession sexuelle, entreprend un voyage psychologique Ã\xa0 la "
#             'recherche de son identitÃ©. Le mari, au bout de son pÃ©riple '
#             'nocturne, revenu de ses dÃ©sirs, ne trouvera finalement auprÃ¨s '
#             "de son Ã©pouse qu'un compromis banal mais complice, les yeux "
#             'ouverts Ã\xa0 tout jamais sur un rÃªve impossible. ',
#  'title': 'Eyes Wide Shut',
#  'year': 1999}
# {'_id': 'movie:38',
#  'actors': [{'_id': 'artist:103', 'role': 'Jack Torrance'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:101'},
#  'genre': 'Horreur',
#  'summary': "Jack Torrance s'installe avec sa femme et son fils Danny dans un "
#             "hÃ´tel fermÃ© Ã\xa0 la morte saison afin d'Ã©crire un roman. Il "
#             'apprend que le gardien prÃ©cÃ©dent a tuÃ© sa femme et ses deux '
#             "filles avant de se suicider. TrÃ¨s vite, Jack va s'apercevoir que "
#             'des choses Ã©tranges se passent autour de lui et que son fils a '
#             'des pouvoirs extrasensoriels... ',
#  'title': 'Shining',
#  'year': 1980}
# {'_id': 'movie:39',
#  'actors': [{'_id': 'artist:35', 'role': '\n                       Mark R'},
#             {'_id': 'artist:95', 'role': 'Marnie Edgar'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:3'},
#  'genre': 'Thriller',
#  'summary': 'Marnie est engagÃ©e comme secrÃ©taire chez un editeur, Mark '
#             "Rutland. Celui-ci amoureux d'elle, dÃ©couvre qu'elle est "
#             "kleptomane et l'oblige Ã\xa0 l'Ã©pouser en la menaÃ§ant de la "
#             "dÃ©noncer. En s'apercevant que Marnie a la phobie de la cou leur "
#             'rouge, Mark tente de remonter dans le passÃ© de la jeune femme '
#             'afin de comprendre les raisons de sa nÃ©vrose. ',
#  'title': 'Pas de printemps pour Marnie',
#  'year': 1964}
# {'_id': 'movie:40',
#  'actors': [],
#  'country': 'USA',
#  'director': {'_id': 'artist:3'},
#  'genre': 'Suspense',
#  'summary': "En repos forcÃ© Ã\xa0 cause d'une jambe plÃ¢trÃ©e, le reporter "
#             'L.B. Jefferies observe au tÃ©lÃ©objectif les voisins de '
#             "l'immeuble d'en face. C'est ainsi qu'il remarque le curieux "
#             "manÃ¨ge d'un reprÃ©sentant de commerce, M. Thorwald, qu'il "
#             "soupconne trÃ¨s vite d'avoir assassinÃ© sa femme... ",
#  'title': 'FenÃªtre sur cour',
#  'year': 1954}
# {'_id': 'movie:41',
#  'actors': [{'_id': 'artist:105', 'role': 'Roger O. Thornhill'},
#             {'_id': 'artist:106', 'role': 'Eve Kendall'},
#             {'_id': 'artist:107', 'role': 'Philipp Vandamm'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:3'},
#  'genre': 'Suspense',
#  'summary': 'Roger Thornhill, publiciste, est pris dans le hall de son hÃ´tel '
#             'pour un certain Kaplan, un espion. Deux hommes tentent de le tuer '
#             "et quand il retrouve l'un de ses agresseurs, celui-ci est "
#             'assassinÃ© devant ses yeux. Pris pour un meurtrier, il est '
#             'obligÃ© de fuir vers Chicago... ',
#  'title': 'La mort aux trousses',
#  'year': 1959}
# {'_id': 'movie:42',
#  'actors': [{'_id': 'artist:80', 'role': None},
#             {'_id': 'artist:112', 'role': "Jeanne d'Arc"},
#             {'_id': 'artist:113', 'role': "Yolande d'Aragon"},
#             {'_id': 'artist:114', 'role': 'Charles VII'},
#             {'_id': 'artist:115', 'role': 'Dunois'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:111'},
#  'genre': 'Guerre',
#  'summary': None,
#  'title': "Jeanne d'Arc",
#  'year': 1999}
# {'_id': 'movie:43',
#  'actors': [{'_id': 'artist:27', 'role': 'Major Korben Dalla'},
#             {'_id': 'artist:112', 'role': 'Leeloo'},
#             {'_id': 'artist:116', 'role': 'Jean-Baptiste Emmanuel Zorg'},
#             {'_id': 'artist:117', 'role': 'Vito Cornelius'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:111'},
#  'genre': 'Science-fiction',
#  'summary': 'Au XXIIIÃ¨me siÃ¨cle, dans un univers Ã©trange et colorÃ©, oÃ¹ '
#             'tout espoir de survie est impossible sans la dÃ©couverte du '
#             'CinquiÃ¨me ElÃ©ment, un hÃ©ros peu ordinaire affronte le mal pour '
#             "sauver l'humanitÃ©. ",
#  'title': 'Le cinquiÃ¨me Ã©lÃ©ment',
#  'year': 1997}
# {'_id': 'movie:44',
#  'actors': [{'_id': 'artist:60', 'role': 'LÃ©on'},
#             {'_id': 'artist:116', 'role': 'Norman Stansfield'},
#             {'_id': 'artist:118', 'role': 'Mathilda'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:111'},
#  'genre': 'Action',
#  'summary': '"LÃ©on est un tueur. Un de la pire espÃ¨ce. Il est introuvable, '
#             "indÃ©tectable, pire qu'un sous-marin. Son ombre est comme une "
#             'menace de danger permanent sur New York. Indestructible LÃ©on ? '
#             "Oui, jusqu'Ã\xa0 ce qu'une petite souris pÃ©nÃ¨tre son univers. "
#             'Une toute petite souris aux yeux immenses..." ',
#  'title': 'LÃ©on',
#  'year': 1994}
# {'_id': 'movie:45',
#  'actors': [{'_id': 'artist:115', 'role': 'Bob'},
#             {'_id': 'artist:119', 'role': 'Nikita'},
#             {'_id': 'artist:120', 'role': 'Marco'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:111'},
#  'genre': 'Thriller',
#  'summary': 'Nikita, droguÃ©e et violente, est prise en mains par des '
#             "psychiatres qui la rÃ©Ã©duquent, la conditionnent, afin d'en "
#             'faire une tueuse Ã\xa0 la botte des Services Secrets. Plus tard, '
#             "rÃ©alisant ce qu'elle est devenue, un pion sans vie privÃ©e que "
#             "l'on manipule, elle tente d'Ã©chapper Ã\xa0 ses commanditaires. ",
#  'title': 'Nikita',
#  'year': 1990}
# {'_id': 'movie:46',
#  'actors': [{'_id': 'artist:39', 'role': 'Johanna'},
#             {'_id': 'artist:60', 'role': 'Enzo Molinari'},
#             {'_id': 'artist:121', 'role': 'Jacques Mayol'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:111'},
#  'genre': 'drama',
#  'summary': "Jacques Mayol et Enzo Molinari se connaissent depuis l'enfance. "
#             "Tous deux experts en apnÃ©e, s'affrontent continuellement pour "
#             'obtenir le record du monde de plongÃ©e. Toujours en rivalitÃ©, '
#             'les deux hommes descendent de plus en plus profond, au risque de '
#             'leurs vies. Le film est ressorti en janvier 89 en version longue '
#             "d'une durÃ©e de 2h40. ",
#  'title': 'Le grand bleu',
#  'year': 1988}
# {'_id': 'movie:47',
#  'actors': [{'_id': 'artist:124', 'role': 'Spider-Man'},
#             {'_id': 'artist:125', 'role': 'Norman Osborn'},
#             {'_id': 'artist:126', 'role': 'Mary Jane Watson'},
#             {'_id': 'artist:127', 'role': 'Oncle Ben'},
#             {'_id': 'artist:128', 'role': 'Tante May'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:187'},
#  'genre': 'Action',
#  'summary': 'Orphelin, Peter Parker est Ã©levÃ© par sa tante May et son oncle '
#             'Ben dans le quartier Queens de New York. Tout en poursuivant ses '
#             "Ã©tudes Ã\xa0 l'universitÃ©, il trouve un emploi de photographe "
#             'au journal Daily Bugle. Il partage son appartement avec Harry '
#             'Osborn, son meilleur ami, et rÃªve de sÃ©duire la belle Mary '
#             'Jane.Cependant, aprÃ¨s avoir Ã©tÃ© mordu par une araignÃ©e '
#             'gÃ©nÃ©tiquement modifiÃ©e, Peter voit son agilitÃ© et sa force '
#             "s'accroÃ®tre et se dÃ©couvre des pouvoirs surnaturels. Devenu "
#             "Spider-Man, il dÃ©cide d'utiliser ses nouvelles capacitÃ©s au "
#             'service du bien.Au mÃªme moment, le pÃ¨re de Harry, le richissime '
#             "industriel Norman Osborn, est victime d'un accident chimique qui "
#             'a dÃ©mesurÃ©ment augmentÃ© ses facultÃ©s intellectuelles et sa '
#             "force, mais l'a rendu fou. Il est devenu le Bouffon Vert, une "
#             'crÃ©ature dÃ©moniaque qui menace la ville. Entre lui et '
#             "Spider-Man, une lutte sans merci s'engage.",
#  'title': 'Spider-Man',
#  'year': 2002}
# {'_id': 'movie:48',
#  'actors': [{'_id': 'artist:63', 'role': 'Jimmy Jump'},
#             {'_id': 'artist:97', 'role': 'Frank White'},
#             {'_id': 'artist:124', 'role': 'Thomas Flanigan'},
#             {'_id': 'artist:131', 'role': 'Dennis Gilley'},
#             {'_id': 'artist:132', 'role': 'Thomas Flanigan'},
#             {'_id': 'artist:217', 'role': 'Test tube'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:122'},
#  'genre': 'drama',
#  'summary': "L'histoire d'un gangster au grand coeur mais aux mÃ©thodes "
#             'dÃ©finitives, surlast_namemÃ© par le presse The King of New York '
#             'et qui rÃªve de fonder un hÃ´pital, confrontÃ© a des policiers '
#             "opiniÃ¢tres qui ont jurÃ© de l'abattre...",
#  'title': 'King of New York',
#  'year': 1990}
# {'_id': 'movie:49',
#  'actors': [{'_id': 'artist:62', 'role': 'Neo'},
#             {'_id': 'artist:63', 'role': 'Morpheus'},
#             {'_id': 'artist:210', 'role': 'Trinity'},
#             {'_id': 'artist:211', 'role': 'Agent Smith'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:61'},
#  'genre': 'Science-fiction',
#  'summary': 'Neo apprend Ã\xa0 mieux contrÃ´ler ses dons naturels, alors mÃªme '
#             "que Sion s'apprÃªte Ã\xa0 tomber sous l'assaut de l'ArmÃ©e des "
#             "Machines. D'ici quelques heures, 250 000 Sentinelles programmÃ©es "
#             'pour anÃ©antir notre espÃ¨ce envahiront la derniÃ¨re enclave '
#             'humaine de la Terre.Mais Morpheus galvanise les citoyens de Sion '
#             "en leur rappelant la Parole de l'Oracle : il est encore temps "
#             "pour l'Elu d'arrÃªter la guerre contre les Machines. Tous les "
#             'espoirs se reportent dÃ¨s lors sur Neo. Au long de sa pÃ©rilleuse '
#             'plongÃ©e au sein de la Matrix et de sa propre destinÃ©e, ce '
#             'dernier sera confrontÃ© Ã\xa0 une rÃ©sistance croissante, une '
#             'vÃ©ritÃ© encore plus aveuglante, un choix encore plus douloureux '
#             "que tout ce qu'il avait jamais imaginÃ©.",
#  'title': 'The Matrix reloaded',
#  'year': 2003}
# {'_id': 'movie:50',
#  'actors': [{'_id': 'artist:62', 'role': 'Neo'},
#             {'_id': 'artist:63', 'role': 'Morpheus'},
#             {'_id': 'artist:134', 'role': 'Agent Smith'},
#             {'_id': 'artist:136', 'role': 'Trinity'},
#             {'_id': 'artist:137', 'role': "L'Oracle"}],
#  'country': 'USA',
#  'director': {'_id': 'artist:135'},
#  'genre': 'Science-fiction',
#  'summary': 'La longue quÃªte de libertÃ© des rebelles culmine en une bataille '
#             "finale explosive. Tandis que l'armÃ©e des Machines sÃ¨me la "
#             'dÃ©solation sur Zion, ses citoyens organisent une dÃ©fense '
#             'acharnÃ©e. Mais pourront-ils retenir les nuÃ©es implacables des '
#             "Sentinelles en attendant que Neo s'approprie l'ensemble de ses "
#             "pouvoirs et mette fin Ã\xa0 la guerre ?L'agent Smith est quant "
#             "Ã\xa0 lui parvenu Ã\xa0 prendre possession de l'esprit de Bane, "
#             "l'un des membres de l'Ã©quipage de l'aÃ©roglisseur. De plus en "
#             "plus puissant, il est dÃ©sormais incontrÃ´lable et n'obÃ©it plus "
#             'aux Machines : il menace de dÃ©truire leur empire ainsi que le '
#             'monde rÃ©el et la Matrice... ',
#  'title': 'The Matrix Revolutions',
#  'year': 2003}
# {'_id': 'movie:51',
#  'actors': [{'_id': 'artist:139', 'role': 'Marcel'},
#             {'_id': 'artist:140', 'role': 'Enseignante'},
#             {'_id': 'artist:141', 'role': 'Bruno'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:138'},
#  'genre': 'drama',
#  'summary': "L'histoire de Bruno, enfant attardÃ© des banlieues et des H.L.M., "
#             'plongÃ© dans la violence de son milieu, et dont la vie va se '
#             'consumer comme une Ã©toile filante.',
#  'title': 'De bruit et de fureur',
#  'year': 1988}
# {'_id': 'movie:52',
#  'actors': [{'_id': 'artist:18', 'role': 'Roger "Verbal" Kint'},
#             {'_id': 'artist:143', 'role': 'Micheal McManus'},
#             {'_id': 'artist:144', 'role': 'Dean Keaton'},
#             {'_id': 'artist:145', 'role': 'Fred Fenster'},
#             {'_id': 'artist:146', 'role': 'Todd Hockney'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:142'},
#  'genre': 'Thriller',
#  'summary': 'Une lÃ©gende du crime contraint cinq malfrats Ã\xa0 aller '
#             "s'aquitter d'une tÃ¢che trÃ¨s pÃ©rilleuse. Ceux qui survivent "
#             'pourront se partager un butin de 90 millions de dollars.',
#  'title': 'Usual suspects',
#  'year': 1995}
# {'_id': 'movie:53',
#  'actors': [{'_id': 'artist:98', 'role': 'Le lieutenant'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:122'},
#  'genre': 'drama',
#  'summary': "La descente aux enfers d'un flic pourri qui enquete sur le viol "
#             "d'une jolie religieuse.",
#  'title': 'Bad Lieutenant',
#  'year': 1992}
# {'_id': 'movie:54',
#  'actors': [{'_id': 'artist:137', 'role': 'Sonny Corleone'},
#             {'_id': 'artist:155', 'role': 'Capt. McCluskey'},
#             {'_id': 'artist:176', 'role': 'Michael Corleone'},
#             {'_id': 'artist:182', 'role': 'Do Vito Corleone'},
#             {'_id': 'artist:183', 'role': 'Kay Adams'},
#             {'_id': 'artist:184', 'role': 'Tom Hagen'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:181'},
#  'genre': 'drama',
#  'summary': 'En 1945, Ã\xa0 New York, les Corleone sont une des cinq familles '
#             'de la mafia. Don Vito Corleone, " parrain " de cette famille, '
#             'marie sa fille Ã\xa0 un bookmaker. Sollozzo, " parrain " de la '
#             'famille Tattaglia, propose Ã\xa0 Don Vito une association dans le '
#             'trafic de drogue, mais celui-ci refuse. Sonny, un de ses fils, y '
#             'est quant Ã\xa0 lui favorable.Afin de traiter avec Sonny, '
#             'Sollozzo tente de faire tuer Don Vito, mais celui-ci en '
#             'rÃ©chappe. Michael, le frÃ¨re cadet de Sonny, recherche alors les '
#             "commanditaires de l'attentat et tue Sollozzo et le chef de la "
#             'police, en reprÃ©sailles.Michael part alors en Sicile, oÃ¹ il '
#             'Ã©pouse Apollonia, mais celle-ci est assassinÃ©e Ã\xa0 sa place. '
#             'De retour Ã\xa0 New York, Michael Ã©pouse Kay Adams et se '
#             'prÃ©pare Ã\xa0 devenir le successeur de son pÃ¨re...',
#  'title': 'Le parrain',
#  'year': 1972}
# {'_id': 'movie:55',
#  'actors': [{'_id': 'artist:167', 'role': 'Don Vito Corleone'},
#             {'_id': 'artist:176', 'role': 'Michael Corleone'},
#             {'_id': 'artist:183', 'role': 'Kay Adams'},
#             {'_id': 'artist:184', 'role': 'Tom Hagen'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:181'},
#  'genre': 'drama',
#  'summary': 'A la mort de Vito Corleone, dit "le Parrain", c\'est son fils, '
#             'Michael, qui reprend les affaires familiales. TrÃ¨s vite, son '
#             'ascension dans le milieu mafiosi est fulgurante.Depuis la mort De '
#             'Don Vito Corleone, son fils, Michael, rÃ¨gne sur la famille. '
#             'AmenÃ© Ã\xa0 nÃ©gocier avec la mafia juive, il perd alors le '
#             "soutien d'un de ses lieutenants, Frankie Pentageli. Echappant de "
#             'justesse Ã\xa0 un attentat, Michael tente de retrouver le '
#             'coupable, soupÃ§onnant Hyman Roth, le chef de la mafia juive.Vito '
#             'Corleone, immigrant italien, arrive Ã\xa0 New York au dÃ©but du '
#             'siÃ¨cle ; trÃ¨s vite, il devient un des caÃ¯ds du quartier, '
#             'utilisant la violence comme moyen de rÃ©gler toutes les affaires. '
#             'Seul au dÃ©part, il bÃ¢tit peu Ã\xa0 peu un vÃ©ritable empire, '
#             'origine de la fortune de la famille des Corleone. ',
#  'title': 'Le parrain II',
#  'year': 1974}
# {'_id': 'movie:56',
#  'actors': [{'_id': 'artist:1', 'role': 'Mary Corleone'},
#             {'_id': 'artist:176', 'role': 'Michael Corleone'},
#             {'_id': 'artist:183', 'role': 'Kay Adams'},
#             {'_id': 'artist:186', 'role': 'Vincent Mancini'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:181'},
#  'genre': 'drama',
#  'summary': 'Atteignant la soixantaine, Michael Corleone dÃ©sire Ã\xa0 la fois '
#             'renouer avec les siens et se rÃ©habiliter aux yeux de la '
#             "sociÃ©tÃ©, surtout de l'Eglise. Il arrivera presque a ses fins, "
#             'mais sa vie passÃ©e et ses anciens ennemis le rattraperont plus '
#             'vite.Michael Corleone est fatiguÃ©. Il veut prendre ses distances '
#             'avec les activitÃ©s mafieuses de sa famille. Il veut convertir '
#             'ces activitÃ©s en affaires lÃ©gales. Kay, son ex-femme, lui fait '
#             "mÃªme accepter que leur fils devienne un chanteur d'opÃ©ra et ne "
#             'reprenne pas les activitÃ©s familiales.Pendant ce temps, la fille '
#             'de Michael, Mary, et son neveu, le fils de Sonny, Vincent, nouent '
#             "une idylle qui n'est pas la bienvenue dans la famille.Il dÃ©cide "
#             "d'aider le Vatican Ã\xa0 renflouer ses caisses et reÃ§oit en "
#             "Ã©change le contrÃ´le d'une entreprise immobiliÃ¨re leur "
#             'appartenant. Attisant la jalousie de ses pairs, Michael Ã©chappe '
#             "de justesse Ã\xa0 un attentat commis par l'un d'eux. Vincent se "
#             'propose alors pour reprendre les affaires de la famille en main.',
#  'title': 'Le parrain III',
#  'year': 1990}
# {'_id': 'movie:57',
#  'actors': [{'_id': 'artist:167', 'role': 'Luis Gara'},
#             {'_id': 'artist:168', 'role': 'Jackie Brown'},
#             {'_id': 'artist:169', 'role': 'Melanie'},
#             {'_id': 'artist:170', 'role': 'Ray Nicolette'},
#             {'_id': 'artist:212', 'role': 'Ordell Robbie'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'crime',
#  'summary': "Jackie Brown, hÃ´tesse de l'air, arrondit ses fins de mois en "
#             "convoyant de l'argent liquide pour le compte d'un trafiquant "
#             "d'armes, Ordell Robbie. Un jour, un agent federal et un policier "
#             "de Los Angeles la cueillent Ã\xa0 l'aÃ©roport. Ils comptent sur "
#             'elle pour faire tomber le trafiquant. Jackie Ã©chafaude alors un '
#             "plan audacieux pour doubler tout le monde lors d'un prochain "
#             'transfert qui porte sur la modeste somme de cinq cent mille '
#             "dollars. Mais il lui faudra compter avec les complices d'Ordell, "
#             'qui ont des mÃ©thodes plutÃ´t expÃ©ditives.',
#  'title': 'Jackie Brown',
#  'year': 1997}
# {'_id': 'movie:58',
#  'actors': [{'_id': 'artist:27', 'role': 'McClane'},
#             {'_id': 'artist:38', 'role': 'Zeus Carver'},
#             {'_id': 'artist:169', 'role': 'Simon Gruber'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:168'},
#  'genre': 'Action',
#  'summary': 'John McClane est cette fois-ci aux prises avec un maÃ®tre '
#             'chanteur, facÃ©tieux et dangereux, qui dÃ©pose des bombes dans '
#             'New York.',
#  'title': 'Une journÃ©e en enfer',
#  'year': 1995}
# {'_id': 'movie:59',
#  'actors': [{'_id': 'artist:27', 'role': 'Malcom Crowe'},
#             {'_id': 'artist:171', 'role': 'Cole Sear'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:170'},
#  'genre': 'Fantastique',
#  'summary': 'Cole Sear, garconnet de huit ans est hantÃ© par un terrible '
#             'secret. Son imaginaire est visitÃ© par des esprits menacants. '
#             'Trop jeune pour comprendre le pourquoi de ces apparitions et '
#             "traumatisÃ© par ces pouvoirs paranormaux, Cole s'enferme dans une "
#             'peur maladive et ne veut reveler Ã\xa0 personne la cause de son '
#             "enfermement, Ã\xa0 l'exception d'un psychologue pour enfants. La "
#             "recherche d'une explication rationnelle guidera l'enfant et le "
#             'thÃ©rapeute vers une vÃ©ritÃ© foudroyante et inexplicable.',
#  'title': 'SixiÃ¨me sens',
#  'year': 1999}
# {'_id': 'movie:60',
#  'actors': [{'_id': 'artist:173', 'role': 'Bob Harris'},
#             {'_id': 'artist:174', 'role': 'Charlotte'},
#             {'_id': 'artist:175', 'role': 'John'},
#             {'_id': 'artist:176', 'role': 'Kelly'},
#             {'_id': 'artist:177', 'role': 'Patron Nightclub'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:172'},
#  'genre': 'romance',
#  'summary': 'Bob Harris, acteur sur le dÃ©clin, se rend Ã\xa0 Tokyo pour '
#             "touner un spot publicitaire. Il a conscience qu'il se trompe - il "
#             'devrait Ãªtre chez lui avec sa famille, jouer au thÃ©Ã¢tre ou '
#             'encore chercher un rÃ´le dans un film -, mais il a besoin '
#             "d'argent.Du haut de son hÃ´tel de luxe, il contemple la ville, "
#             'mais ne voit rien. Il est ailleurs, dÃ©tachÃ© de tout, incapable '
#             "de s'intÃ©grer Ã\xa0 la rÃ©alitÃ© qui l'entoure, incapable "
#             'Ã©galement de dormir Ã\xa0 cause du dÃ©calage horaire.Dans ce '
#             'mÃªme Ã©tablissement, Charlotte, une jeune AmÃ©ricaine '
#             'fraÃ®chement diplÃ´mÃ©e, accompagne son mari, photographe de '
#             "mode. Ce dernier semble s'intÃ©resser davantage Ã\xa0 son travail "
#             "qu'Ã\xa0 sa femme. Se sentant dÃ©laissÃ©e, Charlotte cherche un "
#             "peu d'attention. Elle va en trouver auprÃ¨s de Bob...",
#  'title': 'Lost in Translation',
#  'year': 2003}
# {'_id': 'movie:61',
#  'actors': [{'_id': 'artist:40', 'role': 'La mariÃ©e, alias "Black Mamba"'},
#             {'_id': 'artist:213', 'role': 'O-Ren Ishii'},
#             {'_id': 'artist:214', 'role': 'Bill'},
#             {'_id': 'artist:215', 'role': 'Budd / Sidewinder'},
#             {'_id': 'artist:216', 'role': 'Elle Driver'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'drama',
#  'summary': "Au cours d'une cÃ©rÃ©monie de mariage en plein dÃ©sert, un "
#             'commando fait irruption dans la chapelle et tire sur les '
#             'convives. LaissÃ©e pour morte, la MariÃ©e enceinte retrouve ses '
#             'esprits aprÃ¨s un coma de quatre ans.Celle qui a auparavant '
#             'exercÃ© les fonctions de tueuse Ã\xa0 gages au sein du '
#             "DÃ©tachement International des VipÃ¨res Assassines n'a alors plus "
#             "qu'une seule idÃ©e en tÃªte : venger la mort de ses proches en "
#             "Ã©liminant tous les membres de l'organisation criminelle, dont "
#             "leur chef Bill qu'elle se rÃ©serve pour la fin.",
#  'title': 'Kill Bill',
#  'year': 2003}
# {'_id': 'movie:62',
# ...
#             'Ã\xa0 traquer les frÃ¨res Brittle, les meurtriers quâ€™il '
#             'recherche. Schultz promet Ã\xa0 Django de lui rendre sa libertÃ© '
#             'lorsquâ€™il aura capturÃ© les Brittle â€“ morts ou vifs.Alors que '
#             'les deux hommes pistent les dangereux criminels, Django '
#             'nâ€™oublie pas que son seul but est de retrouver Broomhilda, sa '
#             'femme, dont il fut sÃ©parÃ© Ã\xa0 cause du commerce des '
#             'esclavesâ€¦Lorsque Django et Schultz arrivent dans lâ€™immense '
#             'plantation du puissant Calvin Candie, ils Ã©veillent les '
#             'soupÃ§ons de Stephen, un esclave qui sert Candie et a toute sa '
#             'confiance. Le moindre de leurs mouvements est dÃ©sormais Ã©piÃ© '
#             'par une dangereuse organisation de plus en plus procheâ€¦ Si '
#             'Django et Schultz veulent espÃ©rer sâ€™enfuir avec Broomhilda, '
#             'ils vont devoir choisir entre lâ€™indÃ©pendance et la '
#             'solidaritÃ©, entre le sacrifice et la survieâ€¦',
#  'title': 'Django unchained',
#  'year': 2012}
# {'_id': 'movie:79',
#  'actors': [],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'Guerre',
#  'summary': 'Dans la France occupÃ©e de 1940, Shosanna Dreyfus assiste Ã\xa0 '
#             "l'exÃ©cution de sa famille tombÃ©e entre les mains du colonel "
#             "nazi Hans Landa. Shosanna s'Ã©chappe de justesse et s'enfuit "
#             'Ã\xa0 Paris oÃ¹ elle se construit une nouvelle identitÃ© en '
#             "devenant exploitante d'une salle de cinÃ©ma.Quelque part ailleurs "
#             'en Europe, le lieutenant Aldo Raine forme un groupe de soldats '
#             'juifs amÃ©ricains pour mener des actions punitives '
#             'particuliÃ¨rement sanglantes contre les nazis. "Les bÃ¢tards", '
#             'last_name sous lequel leurs ennemis vont apprendre Ã\xa0 les '
#             "connaÃ®tre, se joignent Ã\xa0 l'actrice allemande et agent secret "
#             "Bridget von Hammersmark pour tenter d'Ã©liminer les hauts "
#             'dignitaires du TroisiÃ¨me Reich. Leurs destins vont se jouer '
#             "Ã\xa0 l'entrÃ©e du cinÃ©ma oÃ¹ Shosanna est dÃ©cidÃ©e Ã\xa0 "
#             'mettre Ã\xa0 exÃ©cution une vengeance trÃ¨s personnelle... ',
#  'title': 'Inglourious Basterds',
#  'year': 209}
# {'_id': 'movie:80',
#  'actors': [{'_id': 'artist:32', 'role': 'Lt. Aldo Raine'},
#             {'_id': 'artist:256', 'role': 'Col. Hans Landa'},
#             {'_id': 'artist:257', 'role': 'Shoshana'},
#             {'_id': 'artist:258', 'role': 'Lt. Archie Hicox'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'Guerre',
#  'summary': 'Dans la France occupÃ©e de 1940, Shosanna Dreyfus assiste Ã\xa0 '
#             "l'exÃ©cution de sa famille tombÃ©e entre les mains du colonel "
#             "nazi Hans Landa. Shosanna s'Ã©chappe de justesse et s'enfuit "
#             'Ã\xa0 Paris oÃ¹ elle se construit une nouvelle identitÃ© en '
#             "devenant exploitante d'une salle de cinÃ©ma.Quelque part ailleurs "
#             'en Europe, le lieutenant Aldo Raine forme un groupe de soldats '
#             'juifs amÃ©ricains pour mener des actions punitives '
#             'particuliÃ¨rement sanglantes contre les nazis. "Les bÃ¢tards", '
#             'last_name sous lequel leurs ennemis vont apprendre Ã\xa0 les '
#             "connaÃ®tre, se joignent Ã\xa0 l'actrice allemande et agent secret "
#             "Bridget von Hammersmark pour tenter d'Ã©liminer les hauts "
#             'dignitaires du TroisiÃ¨me Reich. Leurs destins vont se jouer '
#             "Ã\xa0 l'entrÃ©e du cinÃ©ma oÃ¹ Shosanna est dÃ©cidÃ©e Ã\xa0 "
#             'mettre Ã\xa0 exÃ©cution une vengeance trÃ¨s personnelle... ',
#  'title': 'Inglourious Basterds',
#  'year': 2009}
# {'_id': 'movie:81',
#  'actors': [{'_id': 'artist:260', 'role': 'Antoine Doinel'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:259'},
#  'genre': 'drama',
#  'summary': 'Antoine a une adolescence turbulente. Il ment Ã\xa0 ses parents '
#             'indiffÃ©rents Ã\xa0 son sort, vole, fugue. Son seul rÃ©confort, '
#             'il fait les quatre cents coups avec son ami RenÃ©. Un jour, la '
#             "police s'en mÃªle. ",
#  'title': 'Les quatre cents coups',
#  'year': 1959}
# {'_id': 'movie:82',
#  'actors': [{'_id': 'artist:130', 'role': 'Marion Steiner'},
#             {'_id': 'artist:261', 'role': 'Bernard Granger'},
#             {'_id': 'artist:262', 'role': 'Jean-Loup Cottins'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:259'},
#  'genre': 'drama',
#  'summary': 'Paris, septembre 1942. Lucas Steiner, le directeur du thÃ©Ã¢tre '
#             'Montmartre a dÃ» fuir parce quâ€™il est juif. Sa femme Marion '
#             'Steiner dirige le thÃ©Ã¢tre et engage Bernard Granger, transfuge '
#             'du Grand Guignol, pour jouer Ã\xa0 ses cÃ´tÃ©s dans Â« la '
#             'Disparue Â», que met en scÃ¨ne Jean-Louis Cottins. Jusquâ€™au '
#             'soir de la gÃ©nÃ©rale, la troupe subit les menaces du virulent '
#             'critique de Â« Je suis partout Â», Daxiat, dont lâ€™ambition est '
#             'de diriger la ComÃ©die-FranÃ§aise. Et si, par amour pour sa '
#             'femme, Lucas Steiner avait fait semblant de fuir la France et '
#             'Ã©tait restÃ© cachÃ© dans la cave de son thÃ©Ã¢tre pendant toute '
#             'la guerreâ€¦. ',
#  'title': 'Le dernier mÃ©tro',
#  'year': 1980}
# {'_id': 'movie:84',
#  'actors': [{'_id': 'artist:264', 'role': 'Lt. Col. Kirby Yorke'},
#             {'_id': 'artist:265', 'role': 'Mrs. Kathleen Yorke'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:263'},
#  'genre': 'Western',
#  'summary': 'Colonel de la cavalerie amÃ©ricaine, Kirby York acceuille dans '
#             'son rÃ©giment son propre fils, le jeune Jeff, recalÃ© Ã\xa0 West '
#             'Point. SÃ©parÃ©e de York depuis un Ã©pisode tragique de la Guerre '
#             'de SÃ©cession, Kathleen, la mÃ¨re de Jeff, intervient auprÃ¨s de '
#             "son Ã©poux pour qu'il n'accepte pas le jeune homme dans sa "
#             'garnison. La guerre contre les Indiens fait rage, et la mÃ¨re '
#             'craint pour la vie de son fils. Une terrible bataille contre les '
#             "Apaches s'annonce... ",
#  'title': 'Rio Grande',
#  'year': 1950}
# {'_id': 'movie:85',
#  'actors': [{'_id': 'artist:267', 'role': 'Cooper'},
#             {'_id': 'artist:268', 'role': '   Brand '},
#             {'_id': 'artist:269', 'role': 'Professor Brand'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Science-fiction',
#  'summary': 'Le film raconte les aventures dâ€™un groupe dâ€™explorateurs qui '
#             'utilisent une faille rÃ©cemment dÃ©couverte dans lâ€™espace-temps '
#             'afin de repousser les limites humaines et partir Ã\xa0 la '
#             'conquÃªte des distances astrolast_nameiques dans un voyage '
#             'interstellaire.',
#  'title': 'Interstellar',
#  'year': 2014}
# {'_id': 'movie:86',
#  'actors': [{'_id': 'artist:110', 'role': 'Cobb'},
#             {'_id': 'artist:269', 'role': 'Miles'},
#             {'_id': 'artist:270', 'role': 'Ariadne'},
#             {'_id': 'artist:271', 'role': 'Mal'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Science-fiction',
#  'summary': 'Dom Cobb est un voleur expÃ©rimentÃ© â€“ le meilleur qui soit '
#             'dans lâ€™art pÃ©rilleux de lâ€™extraction : sa spÃ©cialitÃ© '
#             'consiste Ã\xa0 sâ€™approprier les secrets les plus prÃ©cieux '
#             'dâ€™un individu, enfouis au plus profond de son subconscient, '
#             'pendant quâ€™il rÃªve et que son esprit est particuliÃ¨rement '
#             'vulnÃ©rable. TrÃ¨s recherchÃ© pour ses talents dans lâ€™univers '
#             'trouble de lâ€™espionnage industriel, Cobb est aussi devenu un '
#             'fugitif traquÃ© dans le monde entier qui a perdu tout ce qui lui '
#             'est cher. Mais une ultime mission pourrait lui permettre de '
#             'retrouver sa vie dâ€™avant â€“ Ã\xa0 condition quâ€™il puisse '
#             'accomplir lâ€™impossible : lâ€™inception. Au lieu de subtiliser '
#             'un rÃªve, Cobb et son Ã©quipe doivent faire lâ€™inverse : '
#             'implanter une idÃ©e dans lâ€™esprit dâ€™un individu. Sâ€™ils y '
#             'parviennent, il pourrait sâ€™agir du crime parfait. Et pourtant, '
#             'aussi mÃ©thodiques et douÃ©s soient-ils, rien nâ€™aurait pu '
#             'prÃ©parer Cobb et ses partenaires Ã\xa0 un ennemi redoutable qui '
#             'semble avoir systÃ©matiquement un coup dâ€™avance sur eux. Un '
#             'ennemi dont seul Cobb aurait pu soupÃ§onner lâ€™existence. ',
#  'title': 'Inception',
#  'year': 2010}
# {'_id': 'movie:87',
#  'actors': [{'_id': 'artist:272', 'role': 'Leonard'},
#             {'_id': 'artist:273', 'role': 'Natalie'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Thriller',
#  'summary': 'Leonard Shelby ne porte que des costumes de grands couturiers et '
#             "ne se dÃ©place qu'au volant de sa Jaguar. En revanche, il habite "
#             "dans des motels miteux et rÃ¨gle ses notes avec d'Ã©paisses "
#             "liasses de billets.Leonard n'a qu'une idÃ©e en tÃªte : traquer "
#             "l'homme qui a violÃ© et assassinÃ© sa femme afin de se venger. Sa "
#             'recherche du meurtrier est rendue plus difficile par le fait '
#             "qu'il souffre d'une forme rare et incurable d'amnÃ©sie. Bien "
#             "qu'il puisse se souvenir de dÃ©tails de son passÃ©, il est "
#             "incapable de savoir ce qu'il a fait dans le quart d'heure "
#             'prÃ©cÃ©dent, oÃ¹ il se trouve, oÃ¹ il va et pourquoi.Pour ne '
#             'jamais perdre son objectif de vue, il a structurÃ© sa vie Ã\xa0 '
#             "l'aide de fiches, de notes, de photos, de tatouages sur le corps. "
#             "C'est ce qui l'aide Ã\xa0 garder contact avec sa mission, Ã\xa0 "
#             'retenir les informations et Ã\xa0 garder une trace, une notion de '
#             "l'espace et du temps. ",
#  'title': 'Memento',
#  'year': 2000}
# {'_id': 'movie:88',
#  'actors': [{'_id': 'artist:22', 'role': 'Lucius Fox '},
#             {'_id': 'artist:116', 'role': ' Jim Gordon '},
#             {'_id': 'artist:269', 'role': 'Alfred'},
#             {'_id': 'artist:274', 'role': ' Bruce Wayne / Batman '},
#             {'_id': 'artist:275', 'role': 'Ducard'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Thriller',
#  'summary': 'Comment un homme seul peut-il changer le monde ? Telle est la '
#             'question qui hante Bruce Wayne depuis cette nuit tragique oÃ¹ ses '
#             'parents furent abattus sous ses yeux, dans une ruelle de Gotham '
#             'City. TorturÃ© par un profond sentiment de colÃ¨re et de '
#             'culpabilitÃ©, le jeune hÃ©ritier de cette richissime famille fuit '
#             'Gotham pour un long et discret voyage Ã\xa0 travers le monde. Le '
#             'but de ses pÃ©rÃ©grinations : sublimer sa soif de vengeance en '
#             "trouvant de nouveaux moyens de lutter contre l'injustice.",
#  'title': 'Batman begins',
#  'year': 2005}
# {'_id': 'movie:89',
#  'actors': [{'_id': 'artist:22', 'role': 'Lucius Fox'},
#             {'_id': 'artist:116', 'role': 'Gordon'},
#             {'_id': 'artist:269', 'role': 'Alfred'},
#             {'_id': 'artist:274', 'role': 'Bruce Wayne / Batman'},
#             {'_id': 'artist:276', 'role': 'Joker'},
#             {'_id': 'artist:277', 'role': 'Rachel'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Science-fiction',
#  'summary': 'Dans ce nouveau volet, Batman augmente les mises dans sa guerre '
#             "contre le crime. Avec l'appui du lieutenant de police Jim Gordon "
#             'et du procureur de Gotham, Harvey Dent, Batman vise Ã\xa0 '
#             'Ã©radiquer le crime organisÃ© qui pullule dans la ville. Leur '
#             'association est trÃ¨s efficace mais elle sera bientÃ´t '
#             'bouleversÃ©e par le chaos dÃ©clenchÃ© par un criminel '
#             'extraordinaire que les citoyens de Gotham connaissent sous le '
#             'last_name de Joker. ',
#  'title': 'The Dark Knight',
#  'year': 2008}
# {'_id': 'movie:90',
#  'actors': [{'_id': 'artist:22', 'role': 'Lucius Fox'},
#             {'_id': 'artist:116', 'role': 'Commissioner Gordon'},
#             {'_id': 'artist:268', 'role': 'Selina'},
#             {'_id': 'artist:269', 'role': 'Alfred'},
#             {'_id': 'artist:271', 'role': 'Miranda'},
#             {'_id': 'artist:274', 'role': 'Bruce Wayne / Batman'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Science-fiction',
#  'summary': 'Il y a huit ans, Batman a disparu dans la nuit : lui qui Ã©tait '
#             "un hÃ©ros est alors devenu un fugitif. S'accusant de la mort du "
#             'procureur-adjoint Harvey Dent, le Chevalier Noir a tout sacrifiÃ© '
#             'au last_name de ce que le commissaire Gordon et lui-mÃªme '
#             'considÃ©raient Ãªtre une noble cause. Et leurs actions conjointes '
#             'se sont avÃ©rÃ©es efficaces pour un temps puisque la criminalitÃ© '
#             "a Ã©tÃ© Ã©radiquÃ©e Ã\xa0 Gotham City grÃ¢ce Ã\xa0 l'arsenal de "
#             "lois rÃ©pressif initiÃ© par Dent.Mais c'est un chat â€“ aux "
#             'intentions obscures â€“ aussi rusÃ© que voleur qui va tout '
#             "bouleverser. Ã€ moins que ce ne soit l'arrivÃ©e Ã\xa0 Gotham de "
#             'Bane, terroriste masquÃ©, qui compte bien arracher Bruce Ã\xa0 '
#             "l'exil qu'il s'est imposÃ©. Pourtant, mÃªme si ce dernier est "
#             'prÃªt Ã\xa0 endosser de nouveau la cape et le casque du Chevalier '
#             "Noir, Batman n'est peut-Ãªtre plus de taille Ã\xa0 affronter "
#             'Baneâ€¦',
#  'title': 'The Dark Knight Rises',
#  'year': 2012}
# {'_id': 'movie:91',
#  'actors': [{'_id': 'artist:279', 'role': 'Malik El Djebena '},
#             {'_id': 'artist:280', 'role': 'CÃ©sar Luciani'}],
#  'country': 'FR',
#  'director': {'_id': 'artist:278'},
#  'genre': 'drama',
#  'summary': 'CondamnÃ© Ã\xa0 six ans de prison, Malik El Djebena ne sait ni '
#             'lire, ni Ã©crire. A son arrivÃ©e en Centrale, seul au monde, il '
#             'paraÃ®t plus jeune, plus fragile que les autres dÃ©tenus. Il a 19 '
#             "ans. D'emblÃ©e, il tombe sous la coupe d'un groupe de prisonniers "
#             'corses qui fait rÃ©gner sa loi dans la prison. Le jeune homme '
#             'apprend vite. Au fil des " missions ", il s\'endurcit et gagne la '
#             'confiance des Corses.Mais, trÃ¨s vite, Malik utilise toute son '
#             'intelligence pour dÃ©velopper discrÃ¨tement son propre rÃ©seau...',
#  'title': 'Un prophÃ¨te',
#  'year': 2009}
# {'_id': 'movie:92',
#  'actors': [],
#  'country': 'FR',
#  'director': {'_id': 'artist:281'},
#  'genre': 'drama',
#  'summary': 'Dâ€™un petit village du sud de lâ€™Iran aux citÃ©s parisiennes, '
#             'Kheiron nous raconte le destin hors du commun de ses parents '
#             'Hibat et Fereshteh, Ã©ternels optimistes, dans une comÃ©die aux '
#             'airs de conte universel qui Ã©voque lâ€™amour familial, le don de '
#             'soi et surtout lâ€™idÃ©al dâ€™un vivre-ensemble. ',
#  'title': 'Nous trois ou rien',
#  'year': 2015}
# {'title': '58 minutes pour vivre'}
# {'title': 'Alien'}
# {'title': 'American Beauty'}
# {'title': 'Bad Lieutenant'}
# {'title': 'Batman begins'}
# {'title': 'Blade Runner'}
# {'title': 'Casino'}
# {'title': 'Casino Royale'}
# {'title': 'De bruit et de fureur'}
# {'title': 'Django unchained'}
# {'title': 'Eyes Wide Shut'}
# {'title': 'Fargo'}
# {'title': 'Volte/Face'}
# {'title': 'Vertigo'}
# {'title': 'Van Gogh'}
# {'title': 'Usual suspects'}
# {'title': 'Une journÃ©e en enfer'}
# {'title': 'Un prophÃ¨te'}
# {'title': 'Twelve Monkeys'}
# {'title': 'Top Gun'}
# {'title': 'Titanic'}
# {'title': 'The Matrix reloaded'}
# {'title': 'The Matrix Revolutions'}
# {'title': 'The Dark Knight Rises'}
# 2
# <ipython-input-10-03e35e693be5>:71: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   v1979 = movies2.find({"year": 1979},{ "_id": 0, "title": 1, "year":1 }).count()

# %%
for x in movies2.find({"$or" : [{"year": 1997}, {"actors._id": "artist:147"}] }).limit(3):
    pprint(x)
# Out:
# {'_id': 'movie:3',
#  'actors': [{'_id': 'artist:109', 'role': 'Rose DeWitt Bukater'},
#             {'_id': 'artist:110', 'role': 'Jack Dawson'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:6'},
#  'genre': 'drama',
#  'summary': 'Conduite par Brock Lovett, une expÃ©dition amÃ©ricaine fouillant '
#             "l'Ã©pave du Titanic remonte Ã\xa0 la surface le croquis d'une "
#             'femme nue. AlertÃ©e par les mÃ©dias la dame en question, Rose '
#             "DeWitt Bukater, aujourd'hui centenaire, rejoint les lieux du "
#             "naufrage, d'oÃ¹ elle entreprend de conter le rÃ©cit de son "
#             'fascinant, Ã©trange et tragique voyage... ',
#  'title': 'Titanic',
#  'year': 1997}
# {'_id': 'movie:5',
#  'actors': [{'_id': 'artist:11', 'role': 'Sean Archer/Castor Troy'},
#             {'_id': 'artist:12', 'role': 'Castor Troy/Sean Archer'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:10'},
#  'genre': 'Action',
#  'summary': "Directeur d'une unitÃ© anti-terroriste, Sean Archer recherche "
#             'Castor Troy, un criminel responsable de la mort de son fils six '
#             "ans plus tÃ´t. Il parvient Ã\xa0 l'arrÃªter mais apprend que Troy "
#             'a cachÃ© une bombe au Palais des CongrÃ¨s de Los Angeles. Seul le '
#             "frÃ¨re de Troy peut la dÃ©samorcer et, pour l'approcher, Archer "
#             'se fait greffer le visage de Troy. ',
#  'title': 'Volte/Face',
#  'year': 1997}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'drama',
#  'summary': 'Le gÃ©nÃ©ral romain Maximus est le plus '
#             "fidÃ¨le                    soutien de l'empereur Marc AurÃ¨le, "
#             "qu'il a                    conduit de victoire en victoire avec "
#             'une                    bravoure et un dÃ©vouement '
#             'exemplaires.                    Jaloux du prestige de Maximus, et '
#             "plus                    encore de l'amour que lui voue "
#             "l'empereur,                    le fils de Marc-AurÃ¨le, Commode, "
#             "s'arroge                    brutalement le pouvoir, puis "
#             "ordonne                    l'arrestation du gÃ©nÃ©ral et son "
#             'exÃ©cution.                    Maximus Ã©chappe Ã\xa0 ses '
#             'assassins mais ne peut                    empÃªcher le massacre '
#             'de sa famille. CapturÃ©                    par un marchand '
#             "d'esclaves, il devient                    gladiateur et prÃ©pare "
#             'sa vengeance.',
#  'title': 'Gladiator',
#  'year': 2000}

# %%
for x in movies2.find({"$and" : [{"year": 1997}, {"actors.role": "Jack Dawson"}]} ):
    pprint(x)
for x in movies2.find({"year": 1997, "actors.role": "Jack Dawson"} ):
    pprint(x)
# Out:
# {'_id': 'movie:3',
#  'actors': [{'_id': 'artist:109', 'role': 'Rose DeWitt Bukater'},
#             {'_id': 'artist:110', 'role': 'Jack Dawson'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:6'},
#  'genre': 'drama',
#  'summary': 'Conduite par Brock Lovett, une expÃ©dition amÃ©ricaine fouillant '
#             "l'Ã©pave du Titanic remonte Ã\xa0 la surface le croquis d'une "
#             'femme nue. AlertÃ©e par les mÃ©dias la dame en question, Rose '
#             "DeWitt Bukater, aujourd'hui centenaire, rejoint les lieux du "
#             "naufrage, d'oÃ¹ elle entreprend de conter le rÃ©cit de son "
#             'fascinant, Ã©trange et tragique voyage... ',
#  'title': 'Titanic',
#  'year': 1997}
# {'_id': 'movie:3',
#  'actors': [{'_id': 'artist:109', 'role': 'Rose DeWitt Bukater'},
#             {'_id': 'artist:110', 'role': 'Jack Dawson'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:6'},
#  'genre': 'drama',
#  'summary': 'Conduite par Brock Lovett, une expÃ©dition amÃ©ricaine fouillant '
#             "l'Ã©pave du Titanic remonte Ã\xa0 la surface le croquis d'une "
#             'femme nue. AlertÃ©e par les mÃ©dias la dame en question, Rose '
#             "DeWitt Bukater, aujourd'hui centenaire, rejoint les lieux du "
#             "naufrage, d'oÃ¹ elle entreprend de conter le rÃ©cit de son "
#             'fascinant, Ã©trange et tragique voyage... ',
#  'title': 'Titanic',
#  'year': 1997}

# %%
for x in movies2.find({"director._id":"artist:4"}, {"country":0, "summary":0, "genre":0}).sort("year", -1):
    pprint(x)
for x in movies2.find({"director._id":"artist:4", "actors.role":"Maximus"}, {"country":0, "summary":0, "genre":0}).sort("year", -1):
    pprint(x)
critere_recherche = {"director._id":"artist:4", "actors.role":"Maximus"}
projection = {"country":0, "summary":0, "genre":0}
tri = '("year", -1)'
for x in movies2.find(critere_recherche, projection).sort(tri):
    pprint(x)
for x in movies2.find( {"year": { "$gte": 2000, "$lte": 2005 }}):
    pprint(x)
# Out:
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'director': {'_id': 'artist:4'},
#  'title': 'Gladiator',
#  'year': 2000}
# {'_id': 'movie:10',
#  'actors': [{'_id': 'artist:24', 'role': 'Deckard'},
#             {'_id': 'artist:25', 'role': 'Batty'}],
#  'director': {'_id': 'artist:4'},
#  'title': 'Blade Runner',
#  'year': 1982}
# {'_id': 'movie:2',
#  'actors': [{'_id': 'artist:5', 'role': 'Ripley'}],
#  'director': {'_id': 'artist:4'},
#  'title': 'Alien',
#  'year': 1979}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'director': {'_id': 'artist:4'},
#  'title': 'Gladiator',
#  'year': 2000}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'director': {'_id': 'artist:4'},
#  'title': 'Gladiator',
#  'year': 2000}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'drama',
#  'summary': 'Le gÃ©nÃ©ral romain Maximus est le plus '
#             "fidÃ¨le                    soutien de l'empereur Marc AurÃ¨le, "
#             "qu'il a                    conduit de victoire en victoire avec "
#             'une                    bravoure et un dÃ©vouement '
#             'exemplaires.                    Jaloux du prestige de Maximus, et '
#             "plus                    encore de l'amour que lui voue "
#             "l'empereur,                    le fils de Marc-AurÃ¨le, Commode, "
#             "s'arroge                    brutalement le pouvoir, puis "
#             "ordonne                    l'arrestation du gÃ©nÃ©ral et son "
#             'exÃ©cution.                    Maximus Ã©chappe Ã\xa0 ses '
#             'assassins mais ne peut                    empÃªcher le massacre '
#             'de sa famille. CapturÃ©                    par un marchand '
#             "d'esclaves, il devient                    gladiateur et prÃ©pare "
#             'sa vengeance.',
#  'title': 'Gladiator',
#  'year': 2000}
# {'_id': 'movie:47',
#  'actors': [{'_id': 'artist:124', 'role': 'Spider-Man'},
#             {'_id': 'artist:125', 'role': 'Norman Osborn'},
#             {'_id': 'artist:126', 'role': 'Mary Jane Watson'},
#             {'_id': 'artist:127', 'role': 'Oncle Ben'},
#             {'_id': 'artist:128', 'role': 'Tante May'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:187'},
#  'genre': 'Action',
#  'summary': 'Orphelin, Peter Parker est Ã©levÃ© par sa tante May et son oncle '
#             'Ben dans le quartier Queens de New York. Tout en poursuivant ses '
#             "Ã©tudes Ã\xa0 l'universitÃ©, il trouve un emploi de photographe "
#             'au journal Daily Bugle. Il partage son appartement avec Harry '
#             'Osborn, son meilleur ami, et rÃªve de sÃ©duire la belle Mary '
#             'Jane.Cependant, aprÃ¨s avoir Ã©tÃ© mordu par une araignÃ©e '
#             'gÃ©nÃ©tiquement modifiÃ©e, Peter voit son agilitÃ© et sa force '
#             "s'accroÃ®tre et se dÃ©couvre des pouvoirs surnaturels. Devenu "
#             "Spider-Man, il dÃ©cide d'utiliser ses nouvelles capacitÃ©s au "
#             'service du bien.Au mÃªme moment, le pÃ¨re de Harry, le richissime '
#             "industriel Norman Osborn, est victime d'un accident chimique qui "
#             'a dÃ©mesurÃ©ment augmentÃ© ses facultÃ©s intellectuelles et sa '
#             "force, mais l'a rendu fou. Il est devenu le Bouffon Vert, une "
#             'crÃ©ature dÃ©moniaque qui menace la ville. Entre lui et '
#             "Spider-Man, une lutte sans merci s'engage.",
#  'title': 'Spider-Man',
#  'year': 2002}
# {'_id': 'movie:49',
#  'actors': [{'_id': 'artist:62', 'role': 'Neo'},
#             {'_id': 'artist:63', 'role': 'Morpheus'},
#             {'_id': 'artist:210', 'role': 'Trinity'},
#             {'_id': 'artist:211', 'role': 'Agent Smith'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:61'},
#  'genre': 'Science-fiction',
#  'summary': 'Neo apprend Ã\xa0 mieux contrÃ´ler ses dons naturels, alors mÃªme '
#             "que Sion s'apprÃªte Ã\xa0 tomber sous l'assaut de l'ArmÃ©e des "
#             "Machines. D'ici quelques heures, 250 000 Sentinelles programmÃ©es "
#             'pour anÃ©antir notre espÃ¨ce envahiront la derniÃ¨re enclave '
#             'humaine de la Terre.Mais Morpheus galvanise les citoyens de Sion '
#             "en leur rappelant la Parole de l'Oracle : il est encore temps "
#             "pour l'Elu d'arrÃªter la guerre contre les Machines. Tous les "
#             'espoirs se reportent dÃ¨s lors sur Neo. Au long de sa pÃ©rilleuse '
#             'plongÃ©e au sein de la Matrix et de sa propre destinÃ©e, ce '
#             'dernier sera confrontÃ© Ã\xa0 une rÃ©sistance croissante, une '
#             'vÃ©ritÃ© encore plus aveuglante, un choix encore plus douloureux '
#             "que tout ce qu'il avait jamais imaginÃ©.",
#  'title': 'The Matrix reloaded',
#  'year': 2003}
# {'_id': 'movie:50',
#  'actors': [{'_id': 'artist:62', 'role': 'Neo'},
#             {'_id': 'artist:63', 'role': 'Morpheus'},
#             {'_id': 'artist:134', 'role': 'Agent Smith'},
#             {'_id': 'artist:136', 'role': 'Trinity'},
#             {'_id': 'artist:137', 'role': "L'Oracle"}],
#  'country': 'USA',
#  'director': {'_id': 'artist:135'},
#  'genre': 'Science-fiction',
#  'summary': 'La longue quÃªte de libertÃ© des rebelles culmine en une bataille '
#             "finale explosive. Tandis que l'armÃ©e des Machines sÃ¨me la "
#             'dÃ©solation sur Zion, ses citoyens organisent une dÃ©fense '
#             'acharnÃ©e. Mais pourront-ils retenir les nuÃ©es implacables des '
#             "Sentinelles en attendant que Neo s'approprie l'ensemble de ses "
#             "pouvoirs et mette fin Ã\xa0 la guerre ?L'agent Smith est quant "
#             "Ã\xa0 lui parvenu Ã\xa0 prendre possession de l'esprit de Bane, "
#             "l'un des membres de l'Ã©quipage de l'aÃ©roglisseur. De plus en "
#             "plus puissant, il est dÃ©sormais incontrÃ´lable et n'obÃ©it plus "
#             'aux Machines : il menace de dÃ©truire leur empire ainsi que le '
#             'monde rÃ©el et la Matrice... ',
#  'title': 'The Matrix Revolutions',
#  'year': 2003}
# {'_id': 'movie:60',
#  'actors': [{'_id': 'artist:173', 'role': 'Bob Harris'},
#             {'_id': 'artist:174', 'role': 'Charlotte'},
#             {'_id': 'artist:175', 'role': 'John'},
#             {'_id': 'artist:176', 'role': 'Kelly'},
#             {'_id': 'artist:177', 'role': 'Patron Nightclub'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:172'},
#  'genre': 'romance',
#  'summary': 'Bob Harris, acteur sur le dÃ©clin, se rend Ã\xa0 Tokyo pour '
#             "touner un spot publicitaire. Il a conscience qu'il se trompe - il "
#             'devrait Ãªtre chez lui avec sa famille, jouer au thÃ©Ã¢tre ou '
#             'encore chercher un rÃ´le dans un film -, mais il a besoin '
#             "d'argent.Du haut de son hÃ´tel de luxe, il contemple la ville, "
#             'mais ne voit rien. Il est ailleurs, dÃ©tachÃ© de tout, incapable '
#             "de s'intÃ©grer Ã\xa0 la rÃ©alitÃ© qui l'entoure, incapable "
#             'Ã©galement de dormir Ã\xa0 cause du dÃ©calage horaire.Dans ce '
#             'mÃªme Ã©tablissement, Charlotte, une jeune AmÃ©ricaine '
#             'fraÃ®chement diplÃ´mÃ©e, accompagne son mari, photographe de '
#             "mode. Ce dernier semble s'intÃ©resser davantage Ã\xa0 son travail "
#             "qu'Ã\xa0 sa femme. Se sentant dÃ©laissÃ©e, Charlotte cherche un "
#             "peu d'attention. Elle va en trouver auprÃ¨s de Bob...",
#  'title': 'Lost in Translation',
#  'year': 2003}
# {'_id': 'movie:61',
#  'actors': [{'_id': 'artist:40', 'role': 'La mariÃ©e, alias "Black Mamba"'},
#             {'_id': 'artist:213', 'role': 'O-Ren Ishii'},
#             {'_id': 'artist:214', 'role': 'Bill'},
#             {'_id': 'artist:215', 'role': 'Budd / Sidewinder'},
#             {'_id': 'artist:216', 'role': 'Elle Driver'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:37'},
#  'genre': 'drama',
#  'summary': "Au cours d'une cÃ©rÃ©monie de mariage en plein dÃ©sert, un "
#             'commando fait irruption dans la chapelle et tire sur les '
#             'convives. LaissÃ©e pour morte, la MariÃ©e enceinte retrouve ses '
#             'esprits aprÃ¨s un coma de quatre ans.Celle qui a auparavant '
#             'exercÃ© les fonctions de tueuse Ã\xa0 gages au sein du '
#             "DÃ©tachement International des VipÃ¨res Assassines n'a alors plus "
#             "qu'une seule idÃ©e en tÃªte : venger la mort de ses proches en "
#             "Ã©liminant tous les membres de l'organisation criminelle, dont "
#             "leur chef Bill qu'elle se rÃ©serve pour la fin.",
#  'title': 'Kill Bill',
#  'year': 2003}
# {'_id': 'movie:62',
#  'actors': [{'_id': 'artist:182', 'role': 'Vassili ZaÃ¯tzev'},
#             {'_id': 'artist:183', 'role': 'major KÃ¶nig'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:34'},
#  'genre': 'drama',
#  'summary': None,
#  'title': 'Stalingrad',
#  'year': 2001}
# {'_id': 'movie:63',
#  'actors': [{'_id': 'artist:20', 'role': 'Frankie Dunn'},
#             {'_id': 'artist:22', 'role': 'Eddie Scrap-Iron Dupris'},
#             {'_id': 'artist:224', 'role': 'Maggie Fitzerald'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:20'},
#  'genre': 'drama',
#  'summary': "Une histoire d'amour tragique et platonique entre une boxeuse et "
#             'un vieil entraÃ®neur de trente ans son aÃ®nÃ©.',
#  'title': 'Million Dollar Baby',
#  'year': 2005}
# {'_id': 'movie:87',
#  'actors': [{'_id': 'artist:272', 'role': 'Leonard'},
#             {'_id': 'artist:273', 'role': 'Natalie'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Thriller',
#  'summary': 'Leonard Shelby ne porte que des costumes de grands couturiers et '
#             "ne se dÃ©place qu'au volant de sa Jaguar. En revanche, il habite "
#             "dans des motels miteux et rÃ¨gle ses notes avec d'Ã©paisses "
#             "liasses de billets.Leonard n'a qu'une idÃ©e en tÃªte : traquer "
#             "l'homme qui a violÃ© et assassinÃ© sa femme afin de se venger. Sa "
#             'recherche du meurtrier est rendue plus difficile par le fait '
#             "qu'il souffre d'une forme rare et incurable d'amnÃ©sie. Bien "
#             "qu'il puisse se souvenir de dÃ©tails de son passÃ©, il est "
#             "incapable de savoir ce qu'il a fait dans le quart d'heure "
#             'prÃ©cÃ©dent, oÃ¹ il se trouve, oÃ¹ il va et pourquoi.Pour ne '
#             'jamais perdre son objectif de vue, il a structurÃ© sa vie Ã\xa0 '
#             "l'aide de fiches, de notes, de photos, de tatouages sur le corps. "
#             "C'est ce qui l'aide Ã\xa0 garder contact avec sa mission, Ã\xa0 "
#             'retenir les informations et Ã\xa0 garder une trace, une notion de '
#             "l'espace et du temps. ",
#  'title': 'Memento',
#  'year': 2000}
# {'_id': 'movie:88',
#  'actors': [{'_id': 'artist:22', 'role': 'Lucius Fox '},
#             {'_id': 'artist:116', 'role': ' Jim Gordon '},
#             {'_id': 'artist:269', 'role': 'Alfred'},
#             {'_id': 'artist:274', 'role': ' Bruce Wayne / Batman '},
#             {'_id': 'artist:275', 'role': 'Ducard'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:266'},
#  'genre': 'Thriller',
#  'summary': 'Comment un homme seul peut-il changer le monde ? Telle est la '
#             'question qui hante Bruce Wayne depuis cette nuit tragique oÃ¹ ses '
#             'parents furent abattus sous ses yeux, dans une ruelle de Gotham '
#             'City. TorturÃ© par un profond sentiment de colÃ¨re et de '
#             'culpabilitÃ©, le jeune hÃ©ritier de cette richissime famille fuit '
#             'Gotham pour un long et discret voyage Ã\xa0 travers le monde. Le '
#             'but de ses pÃ©rÃ©grinations : sublimer sa soif de vengeance en '
#             "trouvant de nouveaux moyens de lutter contre l'injustice.",
#  'title': 'Batman begins',
#  'year': 2005}

# %%
for x in movies2.find({"actors._id": {"$in": ["artist:34","artist:98","artist:1"]}}, {"title":1, "year":1, "actors":1}).sort([("year", 1), ("title", 1)]):
    pprint(x)
for x in movies2.find({"actors._id": {"$all": ["artist:23","artist:147"]}}):
    pprint(x)
for x in movies2.find({"actors._id": {"$nin": ["artist:34", "artist:98", "artist:1"]}}, {"title":1, "year":1, "actors":1}).sort([("year", -1), ("title", -1)]).limit(5):
    pprint(x)
print(movies2.count({"actors": {"$exists": False}}))
print(movies2.count({"actors": []}))
for x  in movies2.find({"actors": []}, {"_id" : 0, "title": 1, "actors" : 1} ):
    pprint(x)
# eastwood = artist.findOne({"first_name": "Clint", "last_name": "Eastwood"})
# for x in movies2.find({"director._id": eastwood['_id']}, {"title": 1, "director._id" : 1}):
#     pprint(x)
# for x in movies2.find({"title": {'$regex': 'RE'}}, {"actors": "null", "summary": 0}):
#     pprint(x)
for x in movies2.find ({"actors._id": "artist:147"}, {"title": 1, "actors": 1} ):
    pprint(x)
for x in movies2.find ({"actors._id": "artist:147"}, {"actors": 0, "summary": 0} ):
    pprint(x)
# Out:
# {'_id': 'movie:56',
#  'actors': [{'_id': 'artist:1', 'role': 'Mary Corleone'},
#             {'_id': 'artist:176', 'role': 'Michael Corleone'},
#             {'_id': 'artist:183', 'role': 'Kay Adams'},
#             {'_id': 'artist:186', 'role': 'Vincent Mancini'}],
#  'title': 'Le parrain III',
#  'year': 1990}
# {'_id': 'movie:53',
#  'actors': [{'_id': 'artist:98', 'role': 'Le lieutenant'}],
#  'title': 'Bad Lieutenant',
#  'year': 1992}
# {'_id': 'movie:36',
#  'actors': [{'_id': 'artist:37', 'role': 'Mr. Brown'},
#             {'_id': 'artist:98', 'role': 'Mr. White/Larry'},
#             {'_id': 'artist:99', 'role': 'Freddy Newendyke/Mr. Orange'},
#             {'_id': 'artist:100', 'role': 'Nice Guy Eddie'},
#             {'_id': 'artist:215', 'role': 'Mr Blonde'},
#             {'_id': 'artist:217', 'role': 'Mr Pink'},
#             {'_id': 'artist:218', 'role': 'Mr Blue'}],
#  'title': 'Reservoir dogs',
#  'year': 1992}
# {'_id': 'movie:17',
#  'actors': [{'_id': 'artist:11', 'role': 'Vincent Vega'},
#             {'_id': 'artist:27', 'role': 'Butch Coolidge'},
#             {'_id': 'artist:37', 'role': 'Jimmy Dimmick'},
#             {'_id': 'artist:38', 'role': 'Jules Winnfield'},
#             {'_id': 'artist:39', 'role': 'Jody'},
#             {'_id': 'artist:40', 'role': 'Mia Wallace'},
#             {'_id': 'artist:97', 'role': 'Capt. Koons'},
#             {'_id': 'artist:98', 'role': 'Winston "The Wolf" Wolfe'},
#             {'_id': 'artist:99', 'role': 'Pumpkin (Ringo)'}],
#  'title': 'Pulp fiction',
#  'year': 1994}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'drama',
#  'summary': 'Le gÃ©nÃ©ral romain Maximus est le plus '
#             "fidÃ¨le                    soutien de l'empereur Marc AurÃ¨le, "
#             "qu'il a                    conduit de victoire en victoire avec "
#             'une                    bravoure et un dÃ©vouement '
#             'exemplaires.                    Jaloux du prestige de Maximus, et '
#             "plus                    encore de l'amour que lui voue "
#             "l'empereur,                    le fils de Marc-AurÃ¨le, Commode, "
#             "s'arroge                    brutalement le pouvoir, puis "
#             "ordonne                    l'arrestation du gÃ©nÃ©ral et son "
#             'exÃ©cution.                    Maximus Ã©chappe Ã\xa0 ses '
#             'assassins mais ne peut                    empÃªcher le massacre '
#             'de sa famille. CapturÃ©                    par un marchand '
#             "d'esclaves, il devient                    gladiateur et prÃ©pare "
#             'sa vengeance.',
#  'title': 'Gladiator',
#  'year': 2000}
# {'_id': 'movie:92', 'actors': [], 'title': 'Nous trois ou rien', 'year': 2015}
# {'_id': 'movie:85',
#  'actors': [{'_id': 'artist:267', 'role': 'Cooper'},
#             {'_id': 'artist:268', 'role': '   Brand '},
#             {'_id': 'artist:269', 'role': 'Professor Brand'}],
#  'title': 'Interstellar',
#  'year': 2014}
# {'_id': 'movie:90',
#  'actors': [{'_id': 'artist:22', 'role': 'Lucius Fox'},
#             {'_id': 'artist:116', 'role': 'Commissioner Gordon'},
#             {'_id': 'artist:268', 'role': 'Selina'},
#             {'_id': 'artist:269', 'role': 'Alfred'},
#             {'_id': 'artist:271', 'role': 'Miranda'},
#             {'_id': 'artist:274', 'role': 'Bruce Wayne / Batman'}],
#  'title': 'The Dark Knight Rises',
#  'year': 2012}
# {'_id': 'movie:78',
#  'actors': [{'_id': 'artist:110', 'role': 'Calvin Candie'},
#             {'_id': 'artist:212', 'role': 'Stephen'},
#             {'_id': 'artist:255', 'role': 'Django'},
#             {'_id': 'artist:256', 'role': 'Dr. King Schultz'}],
#  'title': 'Django unchained',
#  'year': 2012}
# {'_id': 'movie:86',
#  'actors': [{'_id': 'artist:110', 'role': 'Cobb'},
#             {'_id': 'artist:269', 'role': 'Miles'},
#             {'_id': 'artist:270', 'role': 'Ariadne'},
#             {'_id': 'artist:271', 'role': 'Mal'}],
#  'title': 'Inception',
#  'year': 2010}
# 0
# 6
# {'actors': [], 'title': 'Sacrifice'}
# {'actors': [], 'title': 'Kagemusha'}
# {'actors': [], 'title': 'FenÃªtre sur cour'}
# {'actors': [], 'title': 'Pour quelques dollars de plus'}
# {'actors': [], 'title': 'Inglourious Basterds'}
# {'actors': [], 'title': 'Nous trois ou rien'}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'title': 'Gladiator'}
# {'_id': 'movie:9',
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'drama',
#  'title': 'Gladiator',
#  'year': 2000}
# <ipython-input-14-daf838ba940b>:7: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   print(movies2.count({"actors": {"$exists": False}}))
# <ipython-input-14-daf838ba940b>:8: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   print(movies2.count({"actors": []}))

# %%
#result = movies2.find({"actors._id":{"$in":["artist:34","artist:98", "artist:1"]}})
R = {"actors._id":{"$in":["artist:34","artist:98","artist:1"]}}
projection = {"title":1, "year":1, "actors":1}
#tri = {"year":1, "title":1}
result = movies2.find(R, projection).sort([("year", 1), ("actors.role", 1)])
for a in result:
    pprint(a)
#movies2.find_one()
# Out:
# {'_id': 'movie:56',
#  'actors': [{'_id': 'artist:1', 'role': 'Mary Corleone'},
#             {'_id': 'artist:176', 'role': 'Michael Corleone'},
#             {'_id': 'artist:183', 'role': 'Kay Adams'},
#             {'_id': 'artist:186', 'role': 'Vincent Mancini'}],
#  'title': 'Le parrain III',
#  'year': 1990}
# {'_id': 'movie:36',
#  'actors': [{'_id': 'artist:37', 'role': 'Mr. Brown'},
#             {'_id': 'artist:98', 'role': 'Mr. White/Larry'},
#             {'_id': 'artist:99', 'role': 'Freddy Newendyke/Mr. Orange'},
#             {'_id': 'artist:100', 'role': 'Nice Guy Eddie'},
#             {'_id': 'artist:215', 'role': 'Mr Blonde'},
#             {'_id': 'artist:217', 'role': 'Mr Pink'},
#             {'_id': 'artist:218', 'role': 'Mr Blue'}],
#  'title': 'Reservoir dogs',
#  'year': 1992}
# {'_id': 'movie:53',
#  'actors': [{'_id': 'artist:98', 'role': 'Le lieutenant'}],
#  'title': 'Bad Lieutenant',
#  'year': 1992}
# {'_id': 'movie:17',
#  'actors': [{'_id': 'artist:11', 'role': 'Vincent Vega'},
#             {'_id': 'artist:27', 'role': 'Butch Coolidge'},
#             {'_id': 'artist:37', 'role': 'Jimmy Dimmick'},
#             {'_id': 'artist:38', 'role': 'Jules Winnfield'},
#             {'_id': 'artist:39', 'role': 'Jody'},
#             {'_id': 'artist:40', 'role': 'Mia Wallace'},
#             {'_id': 'artist:97', 'role': 'Capt. Koons'},
#             {'_id': 'artist:98', 'role': 'Winston "The Wolf" Wolfe'},
#             {'_id': 'artist:99', 'role': 'Pumpkin (Ringo)'}],
#  'title': 'Pulp fiction',
#  'year': 1994}

# %%
for x in movies2.find({"$or" : [{"year": 1997}, {"actors._id": "artist:147"}] }).limit(3):
    pprint(x)
# Out:
# {'_id': 'movie:3',
#  'actors': [{'_id': 'artist:109', 'role': 'Rose DeWitt Bukater'},
#             {'_id': 'artist:110', 'role': 'Jack Dawson'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:6'},
#  'genre': 'drama',
#  'summary': 'Conduite par Brock Lovett, une expÃ©dition amÃ©ricaine fouillant '
#             "l'Ã©pave du Titanic remonte Ã\xa0 la surface le croquis d'une "
#             'femme nue. AlertÃ©e par les mÃ©dias la dame en question, Rose '
#             "DeWitt Bukater, aujourd'hui centenaire, rejoint les lieux du "
#             "naufrage, d'oÃ¹ elle entreprend de conter le rÃ©cit de son "
#             'fascinant, Ã©trange et tragique voyage... ',
#  'title': 'Titanic',
#  'year': 1997}
# {'_id': 'movie:5',
#  'actors': [{'_id': 'artist:11', 'role': 'Sean Archer/Castor Troy'},
#             {'_id': 'artist:12', 'role': 'Castor Troy/Sean Archer'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:10'},
#  'genre': 'Action',
#  'summary': "Directeur d'une unitÃ© anti-terroriste, Sean Archer recherche "
#             'Castor Troy, un criminel responsable de la mort de son fils six '
#             "ans plus tÃ´t. Il parvient Ã\xa0 l'arrÃªter mais apprend que Troy "
#             'a cachÃ© une bombe au Palais des CongrÃ¨s de Los Angeles. Seul le '
#             "frÃ¨re de Troy peut la dÃ©samorcer et, pour l'approcher, Archer "
#             'se fait greffer le visage de Troy. ',
#  'title': 'Volte/Face',
#  'year': 1997}
# {'_id': 'movie:9',
#  'actors': [{'_id': 'artist:23', 'role': 'Maximus'},
#             {'_id': 'artist:147', 'role': 'Commode'},
#             {'_id': 'artist:148', 'role': 'Lucilla'},
#             {'_id': 'artist:149', 'role': 'Marc Aurele'}],
#  'country': 'USA',
#  'director': {'_id': 'artist:4'},
#  'genre': 'drama',
#  'summary': 'Le gÃ©nÃ©ral romain Maximus est le plus '
#             "fidÃ¨le                    soutien de l'empereur Marc AurÃ¨le, "
#             "qu'il a                    conduit de victoire en victoire avec "
#             'une                    bravoure et un dÃ©vouement '
#             'exemplaires.                    Jaloux du prestige de Maximus, et '
#             "plus                    encore de l'amour que lui voue "
#             "l'empereur,                    le fils de Marc-AurÃ¨le, Commode, "
#             "s'arroge                    brutalement le pouvoir, puis "
#             "ordonne                    l'arrestation du gÃ©nÃ©ral et son "
#             'exÃ©cution.                    Maximus Ã©chappe Ã\xa0 ses '
#             'assassins mais ne peut                    empÃªcher le massacre '
#             'de sa famille. CapturÃ©                    par un marchand '
#             "d'esclaves, il devient                    gladiateur et prÃ©pare "
#             'sa vengeance.',
#  'title': 'Gladiator',
#  'year': 2000}
